# %%
import os

file_path = r"C:\Users\cjx02\Desktop\student project_machine learning_06_2022\data\bc"
new_path=r"C:\Users\cjx02\Desktop\student project_machine learning_06_2022\data\bc"

def rename(path):
    i=0
    filelist = os.listdir(path)
    for files in filelist:
        oldDirpath = os.path.join(path,files)
        filename=os.path.splitext(files)[0]
        filetype = os.path.splitext(files)[1]
        newDirPath = os.path.join(new_path,"B_"+str(i)+filetype)
        os.rename(oldDirpath,newDirPath)
        i+=1
    print("total images number:",i)

rename(file_path)
# Out:
# total images number: 32

# %%
file_path = r"C:\Users\cjx02\Desktop\student project_machine learning_06_2022\data\gc"
new_path=r"C:\Users\cjx02\Desktop\student project_machine learning_06_2022\data\gc"
def rename(path):
    i=0
    filelist = os.listdir(path)
    for files in filelist:
        oldDirpath = os.path.join(path,files)
        filename=os.path.splitext(files)[0]
        filetype = os.path.splitext(files)[1]
        newDirPath = os.path.join(new_path,"G_"+str(i)+filetype)
        os.rename(oldDirpath,newDirPath)
        i+=1
    print("total images number:",i)
rename(file_path)
# Out:
# total images number: 2639

# %%
#labeling
import os

def generate(dir,label):
    files = os.listdir(dir+'/gc')
    with open(dir+'val.txt','a+') as f:
        for file in files:
            filename = os.path.split(file)[0]
            filetype = os.path.split(file)[1]
            if filetype == '.txt':
                continue
            name = '/gc' + '/' + file + ' ' + str(int(label)) + '\n'
            print(name)
    print("finished!")
    
img_path = r'C:\Users\cjx02\Desktop\student project_machine learning_06_2022\data'

if __name__ == '__main__':
    i=1
    generate(img_path,i)
# Out:
# /gc/G_0.png 1
#
# /gc/G_1.png 1
#
# /gc/G_10.png 1
#
# /gc/G_100.png 1
#
# /gc/G_1000.png 1
#
# /gc/G_1001.png 1
#
# /gc/G_1002.png 1
#
# /gc/G_1003.png 1
#
# /gc/G_1004.png 1
#
# /gc/G_1005.png 1
#
# /gc/G_1006.png 1
#
# /gc/G_1007.png 1
#
# /gc/G_1008.png 1
#
# /gc/G_1009.png 1
#
# /gc/G_101.png 1
#
# /gc/G_1010.png 1
#
# /gc/G_1011.png 1
#
# /gc/G_1012.png 1
#
# /gc/G_1013.png 1
#
# /gc/G_1014.png 1
#
# /gc/G_1015.png 1
#
# /gc/G_1016.png 1
#
# /gc/G_1017.png 1
#
# /gc/G_1018.png 1
#
# /gc/G_1019.png 1
#
# /gc/G_102.png 1
#
# /gc/G_1020.png 1
#
# /gc/G_1021.png 1
#
# /gc/G_1022.png 1
#
# /gc/G_1023.png 1
#
# /gc/G_1024.png 1
#
# /gc/G_1025.png 1
#
# /gc/G_1026.png 1
#
# /gc/G_1027.png 1
#
# /gc/G_1028.png 1
#
# /gc/G_1029.png 1
#
# /gc/G_103.png 1
#
# /gc/G_1030.png 1
#
# /gc/G_1031.png 1
#
# /gc/G_1032.png 1
#
# /gc/G_1033.png 1
#
# /gc/G_1034.png 1
#
# /gc/G_1035.png 1
#
# /gc/G_1036.png 1
#
# /gc/G_1037.png 1
#
# /gc/G_1038.png 1
#
# /gc/G_1039.png 1
#
# /gc/G_104.png 1
#
# /gc/G_1040.png 1
#
# /gc/G_1041.png 1
#
# /gc/G_1042.png 1
#
# /gc/G_1043.png 1
#
# /gc/G_1044.png 1
#
# /gc/G_1045.png 1
#
# /gc/G_1046.png 1
#
# /gc/G_1047.png 1
#
# /gc/G_1048.png 1
#
# /gc/G_1049.png 1
#
# /gc/G_105.png 1
#
# /gc/G_1050.png 1
#
# /gc/G_1051.png 1
#
# /gc/G_1052.png 1
#
# /gc/G_1053.png 1
#
# /gc/G_1054.png 1
#
# /gc/G_1055.png 1
#
# /gc/G_1056.png 1
#
# /gc/G_1057.png 1
#
# /gc/G_1058.png 1
#
# /gc/G_1059.png 1
#
# /gc/G_106.png 1
#
# /gc/G_1060.png 1
#
# /gc/G_1061.png 1
#
# /gc/G_1062.png 1
#
# /gc/G_1063.png 1
#
# /gc/G_1064.png 1
#
# /gc/G_1065.png 1
#
# /gc/G_1066.png 1
#
# /gc/G_1067.png 1
#
# /gc/G_1068.png 1
#
# /gc/G_1069.png 1
#
# /gc/G_107.png 1
#
# /gc/G_1070.png 1
#
# /gc/G_1071.png 1
#
# /gc/G_1072.png 1
#
# /gc/G_1073.png 1
#
# /gc/G_1074.png 1
#
# /gc/G_1075.png 1
#
# /gc/G_1076.png 1
#
# /gc/G_1077.png 1
#
# /gc/G_1078.png 1
#
# /gc/G_1079.png 1
#
# /gc/G_108.png 1
#
# /gc/G_1080.png 1
#
# /gc/G_1081.png 1
#
# /gc/G_1082.png 1
#
# /gc/G_1083.png 1
#
# /gc/G_1084.png 1
#
# /gc/G_1085.png 1
#
# /gc/G_1086.png 1
#
# /gc/G_1087.png 1
#
# /gc/G_1088.png 1
#
# /gc/G_1089.png 1
#
# /gc/G_109.png 1
#
# /gc/G_1090.png 1
#
# /gc/G_1091.png 1
#
# /gc/G_1092.png 1
#
# /gc/G_1093.png 1
#
# /gc/G_1094.png 1
#
# /gc/G_1095.png 1
#
# /gc/G_1096.png 1
#
# /gc/G_1097.png 1
#
# /gc/G_1098.png 1
#
# /gc/G_1099.png 1
#
# /gc/G_11.png 1
#
# /gc/G_110.png 1
#
# /gc/G_1100.png 1
#
# /gc/G_1101.png 1
#
# /gc/G_1102.png 1
#
# /gc/G_1103.png 1
#
# /gc/G_1104.png 1
#
# /gc/G_1105.png 1
#
# /gc/G_1106.png 1
#
# /gc/G_1107.png 1
#
# /gc/G_1108.png 1
#
# /gc/G_1109.png 1
#
# /gc/G_111.png 1
#
# /gc/G_1110.png 1
#
# /gc/G_1111.png 1
#
# /gc/G_1112.png 1
#
# /gc/G_1113.png 1
#
# /gc/G_1114.png 1
#
# /gc/G_1115.png 1
#
# /gc/G_1116.png 1
#
# /gc/G_1117.png 1
#
# /gc/G_1118.png 1
#
# /gc/G_1119.png 1
#
# /gc/G_112.png 1
#
# /gc/G_1120.png 1
#
# /gc/G_1121.png 1
#
# /gc/G_1122.png 1
#
# /gc/G_1123.png 1
#
# /gc/G_1124.png 1
#
# /gc/G_1125.png 1
#
# /gc/G_1126.png 1
#
# /gc/G_1127.png 1
#
# /gc/G_1128.png 1
#
# /gc/G_1129.png 1
#
# /gc/G_113.png 1
#
# /gc/G_1130.png 1
#
# /gc/G_1131.png 1
#
# /gc/G_1132.png 1
#
# /gc/G_1133.png 1
#
# /gc/G_1134.png 1
#
# /gc/G_1135.png 1
#
# /gc/G_1136.png 1
#
# /gc/G_1137.png 1
#
# /gc/G_1138.png 1
#
# /gc/G_1139.png 1
#
# /gc/G_114.png 1
#
# /gc/G_1140.png 1
#
# /gc/G_1141.png 1
#
# /gc/G_1142.png 1
#
# /gc/G_1143.png 1
#
# /gc/G_1144.png 1
#
# /gc/G_1145.png 1
#
# /gc/G_1146.png 1
#
# /gc/G_1147.png 1
#
# /gc/G_1148.png 1
#
# /gc/G_1149.png 1
#
# /gc/G_115.png 1
#
# /gc/G_1150.png 1
#
# /gc/G_1151.png 1
#
# /gc/G_1152.png 1
#
# /gc/G_1153.png 1
#
# /gc/G_1154.png 1
#
# /gc/G_1155.png 1
#
# /gc/G_1156.png 1
#
# /gc/G_1157.png 1
#
# /gc/G_1158.png 1
#
# /gc/G_1159.png 1
#
# /gc/G_116.png 1
#
# /gc/G_1160.png 1
#
# /gc/G_1161.png 1
#
# /gc/G_1162.png 1
#
# /gc/G_1163.png 1
#
# /gc/G_1164.png 1
#
# /gc/G_1165.png 1
#
# /gc/G_1166.png 1
#
# /gc/G_1167.png 1
#
# /gc/G_1168.png 1
#
# /gc/G_1169.png 1
#
# /gc/G_117.png 1
#
# /gc/G_1170.png 1
#
# /gc/G_1171.png 1
#
# /gc/G_1172.png 1
#
# /gc/G_1173.png 1
#
# /gc/G_1174.png 1
#
# /gc/G_1175.png 1
#
# /gc/G_1176.png 1
#
# /gc/G_1177.png 1
#
# /gc/G_1178.png 1
#
# /gc/G_1179.png 1
#
# /gc/G_118.png 1
#
# /gc/G_1180.png 1
#
# /gc/G_1181.png 1
#
# /gc/G_1182.png 1
#
# /gc/G_1183.png 1
#
# /gc/G_1184.png 1
#
# /gc/G_1185.png 1
#
# /gc/G_1186.png 1
#
# /gc/G_1187.png 1
#
# /gc/G_1188.png 1
#
# /gc/G_1189.png 1
#
# /gc/G_119.png 1
#
# /gc/G_1190.png 1
#
# /gc/G_1191.png 1
#
# /gc/G_1192.png 1
#
# /gc/G_1193.png 1
#
# /gc/G_1194.png 1
#
# /gc/G_1195.png 1
#
# /gc/G_1196.png 1
#
# /gc/G_1197.png 1
#
# /gc/G_1198.png 1
#
# /gc/G_1199.png 1
#
# /gc/G_12.png 1
#
# /gc/G_120.png 1
#
# /gc/G_1200.png 1
#
# /gc/G_1201.png 1
#
# /gc/G_1202.png 1
#
# /gc/G_1203.png 1
#
# /gc/G_1204.png 1
#
# /gc/G_1205.png 1
#
# /gc/G_1206.png 1
#
# /gc/G_1207.png 1
#
# /gc/G_1208.png 1
#
# /gc/G_1209.png 1
#
# /gc/G_121.png 1
#
# /gc/G_1210.png 1
#
# /gc/G_1211.png 1
#
# /gc/G_1212.png 1
#
# /gc/G_1213.png 1
#
# /gc/G_1214.png 1
#
# /gc/G_1215.png 1
#
# /gc/G_1216.png 1
#
# /gc/G_1217.png 1
#
# /gc/G_1218.png 1
#
# /gc/G_1219.png 1
#
# /gc/G_122.png 1
#
# /gc/G_1220.png 1
#
# /gc/G_1221.png 1
#
# /gc/G_1222.png 1
#
# /gc/G_1223.png 1
#
# /gc/G_1224.png 1
#
# /gc/G_1225.png 1
#
# /gc/G_1226.png 1
#
# /gc/G_1227.png 1
#
# /gc/G_1228.png 1
#
# /gc/G_1229.png 1
#
# /gc/G_123.png 1
#
# /gc/G_1230.png 1
#
# /gc/G_1231.png 1
#
# /gc/G_1232.png 1
#
# /gc/G_1233.png 1
#
# /gc/G_1234.png 1
#
# /gc/G_1235.png 1
#
# /gc/G_1236.png 1
#
# /gc/G_1237.png 1
#
# /gc/G_1238.png 1
#
# /gc/G_1239.png 1
#
# /gc/G_124.png 1
#
# /gc/G_1240.png 1
#
# /gc/G_1241.png 1
#
# /gc/G_1242.png 1
#
# /gc/G_1243.png 1
#
# /gc/G_1244.png 1
#
# /gc/G_1245.png 1
#
# /gc/G_1246.png 1
#
# /gc/G_1247.png 1
#
# /gc/G_1248.png 1
#
# /gc/G_1249.png 1
#
# /gc/G_125.png 1
#
# /gc/G_1250.png 1
#
# /gc/G_1251.png 1
#
# /gc/G_1252.png 1
#
# /gc/G_1253.png 1
#
# /gc/G_1254.png 1
#
# /gc/G_1255.png 1
#
# /gc/G_1256.png 1
#
# /gc/G_1257.png 1
#
# /gc/G_1258.png 1
#
# /gc/G_1259.png 1
#
# /gc/G_126.png 1
#
# /gc/G_1260.png 1
#
# /gc/G_1261.png 1
#
# /gc/G_1262.png 1
#
# /gc/G_1263.png 1
#
# /gc/G_1264.png 1
#
# /gc/G_1265.png 1
#
# /gc/G_1266.png 1
#
# /gc/G_1267.png 1
#
# /gc/G_1268.png 1
#
# /gc/G_1269.png 1
#
# /gc/G_127.png 1
#
# /gc/G_1270.png 1
#
# /gc/G_1271.png 1
#
# /gc/G_1272.png 1
#
# /gc/G_1273.png 1
#
# /gc/G_1274.png 1
#
# /gc/G_1275.png 1
#
# /gc/G_1276.png 1
#
# /gc/G_1277.png 1
#
# /gc/G_1278.png 1
#
# /gc/G_1279.png 1
#
# /gc/G_128.png 1
#
# /gc/G_1280.png 1
#
# /gc/G_1281.png 1
#
# /gc/G_1282.png 1
#
# /gc/G_1283.png 1
#
# /gc/G_1284.png 1
#
# /gc/G_1285.png 1
#
# /gc/G_1286.png 1
#
# /gc/G_1287.png 1
#
# /gc/G_1288.png 1
#
# /gc/G_1289.png 1
#
# /gc/G_129.png 1
#
# /gc/G_1290.png 1
#
# /gc/G_1291.png 1
#
# /gc/G_1292.png 1
#
# /gc/G_1293.png 1
#
# /gc/G_1294.png 1
#
# /gc/G_1295.png 1
#
# /gc/G_1296.png 1
#
# /gc/G_1297.png 1
#
# /gc/G_1298.png 1
#
# /gc/G_1299.png 1
#
# /gc/G_13.png 1
#
# /gc/G_130.png 1
#
# /gc/G_1300.png 1
#
# /gc/G_1301.png 1
#
# /gc/G_1302.png 1
#
# /gc/G_1303.png 1
#
# /gc/G_1304.png 1
#
# /gc/G_1305.png 1
#
# /gc/G_1306.png 1
#
# /gc/G_1307.png 1
#
# /gc/G_1308.png 1
#
# /gc/G_1309.png 1
#
# /gc/G_131.png 1
#
# /gc/G_1310.png 1
#
# /gc/G_1311.png 1
#
# /gc/G_1312.png 1
#
# /gc/G_1313.png 1
#
# /gc/G_1314.png 1
#
# /gc/G_1315.png 1
#
# /gc/G_1316.png 1
#
# /gc/G_1317.png 1
#
# /gc/G_1318.png 1
#
# /gc/G_1319.png 1
#
# /gc/G_132.png 1
#
# /gc/G_1320.png 1
#
# /gc/G_1321.png 1
#
# /gc/G_1322.png 1
#
# /gc/G_1323.png 1
#
# /gc/G_1324.png 1
#
# /gc/G_1325.png 1
#
# /gc/G_1326.png 1
#
# /gc/G_1327.png 1
#
# /gc/G_1328.png 1
#
# /gc/G_1329.png 1
#
# /gc/G_133.png 1
#
# /gc/G_1330.png 1
#
# /gc/G_1331.png 1
#
# /gc/G_1332.png 1
#
# /gc/G_1333.png 1
#
# /gc/G_1334.png 1
#
# /gc/G_1335.png 1
#
# /gc/G_1336.png 1
#
# /gc/G_1337.png 1
#
# /gc/G_1338.png 1
#
# /gc/G_1339.png 1
#
# /gc/G_134.png 1
#
# /gc/G_1340.png 1
#
# /gc/G_1341.png 1
#
# /gc/G_1342.png 1
#
# /gc/G_1343.png 1
#
# /gc/G_1344.png 1
#
# /gc/G_1345.png 1
#
# /gc/G_1346.png 1
#
# /gc/G_1347.png 1
#
# /gc/G_1348.png 1
#
# /gc/G_1349.png 1
#
# /gc/G_135.png 1
#
# /gc/G_1350.png 1
#
# /gc/G_1351.png 1
#
# /gc/G_1352.png 1
#
# /gc/G_1353.png 1
#
# /gc/G_1354.png 1
#
# /gc/G_1355.png 1
#
# /gc/G_1356.png 1
#
# /gc/G_1357.png 1
#
# /gc/G_1358.png 1
#
# /gc/G_1359.png 1
#
# /gc/G_136.png 1
#
# /gc/G_1360.png 1
#
# /gc/G_1361.png 1
#
# /gc/G_1362.png 1
#
# /gc/G_1363.png 1
#
# /gc/G_1364.png 1
#
# /gc/G_1365.png 1
#
# /gc/G_1366.png 1
#
# /gc/G_1367.png 1
#
# /gc/G_1368.png 1
#
# /gc/G_1369.png 1
#
# /gc/G_137.png 1
#
# /gc/G_1370.png 1
#
# /gc/G_1371.png 1
#
# /gc/G_1372.png 1
#
# /gc/G_1373.png 1
#
# /gc/G_1374.png 1
#
# /gc/G_1375.png 1
#
# /gc/G_1376.png 1
#
# /gc/G_1377.png 1
#
# /gc/G_1378.png 1
#
# /gc/G_1379.png 1
#
# /gc/G_138.png 1
#
# /gc/G_1380.png 1
#
# /gc/G_1381.png 1
#
# /gc/G_1382.png 1
#
# /gc/G_1383.png 1
#
# /gc/G_1384.png 1
#
# /gc/G_1385.png 1
#
# /gc/G_1386.png 1
#
# /gc/G_1387.png 1
#
# /gc/G_1388.png 1
#
# /gc/G_1389.png 1
#
# /gc/G_139.png 1
#
# /gc/G_1390.png 1
#
# /gc/G_1391.png 1
#
# /gc/G_1392.png 1
#
# /gc/G_1393.png 1
#
# /gc/G_1394.png 1
#
# /gc/G_1395.png 1
#
# /gc/G_1396.png 1
#
# /gc/G_1397.png 1
#
# /gc/G_1398.png 1
#
# /gc/G_1399.png 1
#
# /gc/G_14.png 1
#
# /gc/G_140.png 1
#
# /gc/G_1400.png 1
#
# /gc/G_1401.png 1
#
# /gc/G_1402.png 1
#
# /gc/G_1403.png 1
#
# /gc/G_1404.png 1
#
# /gc/G_1405.png 1
#
# /gc/G_1406.png 1
#
# /gc/G_1407.png 1
#
# /gc/G_1408.png 1
#
# /gc/G_1409.png 1
#
# /gc/G_141.png 1
#
# /gc/G_1410.png 1
#
# /gc/G_1411.png 1
#
# /gc/G_1412.png 1
#
# /gc/G_1413.png 1
#
# /gc/G_1414.png 1
#
# /gc/G_1415.png 1
#
# /gc/G_1416.png 1
#
# /gc/G_1417.png 1
#
# /gc/G_1418.png 1
#
# /gc/G_1419.png 1
#
# /gc/G_142.png 1
#
# /gc/G_1420.png 1
#
# /gc/G_1421.png 1
#
# /gc/G_1422.png 1
#
# /gc/G_1423.png 1
#
# /gc/G_1424.png 1
#
# /gc/G_1425.png 1
#
# /gc/G_1426.png 1
#
# /gc/G_1427.png 1
#
# /gc/G_1428.png 1
#
# /gc/G_1429.png 1
#
# /gc/G_143.png 1
#
# /gc/G_1430.png 1
#
# /gc/G_1431.png 1
#
# /gc/G_1432.png 1
#
# /gc/G_1433.png 1
#
# /gc/G_1434.png 1
#
# /gc/G_1435.png 1
#
# /gc/G_1436.png 1
#
# /gc/G_1437.png 1
#
# /gc/G_1438.png 1
#
# /gc/G_1439.png 1
#
# /gc/G_144.png 1
#
# /gc/G_1440.png 1
#
# /gc/G_1441.png 1
#
# /gc/G_1442.png 1
#
# /gc/G_1443.png 1
#
# /gc/G_1444.png 1
#
# /gc/G_1445.png 1
#
# /gc/G_1446.png 1
#
# /gc/G_1447.png 1
#
# /gc/G_1448.png 1
#
# /gc/G_1449.png 1
#
# /gc/G_145.png 1
#
# /gc/G_1450.png 1
#
# /gc/G_1451.png 1
#
# /gc/G_1452.png 1
#
# /gc/G_1453.png 1
#
# /gc/G_1454.png 1
#
# /gc/G_1455.png 1
#
# /gc/G_1456.png 1
#
# /gc/G_1457.png 1
#
# /gc/G_1458.png 1
#
# /gc/G_1459.png 1
#
# /gc/G_146.png 1
#
# /gc/G_1460.png 1
#
# /gc/G_1461.png 1
#
# /gc/G_1462.png 1
#
# /gc/G_1463.png 1
#
# /gc/G_1464.png 1
#
# /gc/G_1465.png 1
#
# /gc/G_1466.png 1
#
# /gc/G_1467.png 1
#
# /gc/G_1468.png 1
#
# /gc/G_1469.png 1
#
# /gc/G_147.png 1
#
# /gc/G_1470.png 1
#
# /gc/G_1471.png 1
#
# /gc/G_1472.png 1
#
# /gc/G_1473.png 1
#
# /gc/G_1474.png 1
#
# /gc/G_1475.png 1
#
# /gc/G_1476.png 1
#
# /gc/G_1477.png 1
#
# /gc/G_1478.png 1
#
# /gc/G_1479.png 1
#
# /gc/G_148.png 1
#
# /gc/G_1480.png 1
#
# /gc/G_1481.png 1
#
# /gc/G_1482.png 1
#
# /gc/G_1483.png 1
#
# /gc/G_1484.png 1
#
# /gc/G_1485.png 1
#
# /gc/G_1486.png 1
#
# /gc/G_1487.png 1
#
# /gc/G_1488.png 1
#
# /gc/G_1489.png 1
#
# /gc/G_149.png 1
#
# /gc/G_1490.png 1
#
# /gc/G_1491.png 1
#
# /gc/G_1492.png 1
#
# /gc/G_1493.png 1
#
# /gc/G_1494.png 1
#
# /gc/G_1495.png 1
#
# /gc/G_1496.png 1
#
# /gc/G_1497.png 1
#
# /gc/G_1498.png 1
#
# /gc/G_1499.png 1
#
# /gc/G_15.png 1
#
# /gc/G_150.png 1
#
# /gc/G_1500.png 1
#
# /gc/G_1501.png 1
#
# /gc/G_1502.png 1
#
# /gc/G_1503.png 1
#
# /gc/G_1504.png 1
#
# /gc/G_1505.png 1
#
# /gc/G_1506.png 1
#
# /gc/G_1507.png 1
#
# /gc/G_1508.png 1
#
# /gc/G_1509.png 1
#
# /gc/G_151.png 1
#
# /gc/G_1510.png 1
#
# /gc/G_1511.png 1
#
# /gc/G_1512.png 1
#
# /gc/G_1513.png 1
#
# /gc/G_1514.png 1
#
# /gc/G_1515.png 1
#
# /gc/G_1516.png 1
#
# /gc/G_1517.png 1
#
# /gc/G_1518.png 1
#
# /gc/G_1519.png 1
#
# /gc/G_152.png 1
#
# /gc/G_1520.png 1
#
# /gc/G_1521.png 1
#
# /gc/G_1522.png 1
#
# /gc/G_1523.png 1
#
# /gc/G_1524.png 1
#
# /gc/G_1525.png 1
#
# /gc/G_1526.png 1
#
# /gc/G_1527.png 1
#
# /gc/G_1528.png 1
#
# /gc/G_1529.png 1
#
# /gc/G_153.png 1
#
# /gc/G_1530.png 1
#
# /gc/G_1531.png 1
#
# /gc/G_1532.png 1
#
# /gc/G_1533.png 1
#
# /gc/G_1534.png 1
#
# /gc/G_1535.png 1
#
# /gc/G_1536.png 1
#
# /gc/G_1537.png 1
#
# /gc/G_1538.png 1
#
# /gc/G_1539.png 1
#
# /gc/G_154.png 1
#
# /gc/G_1540.png 1
#
# /gc/G_1541.png 1
#
# /gc/G_1542.png 1
#
# /gc/G_1543.png 1
#
# /gc/G_1544.png 1
#
# /gc/G_1545.png 1
#
# /gc/G_1546.png 1
#
# /gc/G_1547.png 1
#
# /gc/G_1548.png 1
#
# /gc/G_1549.png 1
#
# /gc/G_155.png 1
#
# /gc/G_1550.png 1
#
# /gc/G_1551.png 1
#
# /gc/G_1552.png 1
#
# /gc/G_1553.png 1
#
# /gc/G_1554.png 1
#
# /gc/G_1555.png 1
#
# /gc/G_1556.png 1
#
# /gc/G_1557.png 1
#
# /gc/G_1558.png 1
#
# /gc/G_1559.png 1
#
# /gc/G_156.png 1
#
# /gc/G_1560.png 1
#
# /gc/G_1561.png 1
#
# /gc/G_1562.png 1
#
# /gc/G_1563.png 1
#
# /gc/G_1564.png 1
#
# /gc/G_1565.png 1
#
# /gc/G_1566.png 1
#
# /gc/G_1567.png 1
#
# /gc/G_1568.png 1
#
# /gc/G_1569.png 1
#
# /gc/G_157.png 1
#
# /gc/G_1570.png 1
#
# /gc/G_1571.png 1
#
# /gc/G_1572.png 1
#
# /gc/G_1573.png 1
#
# /gc/G_1574.png 1
#
# /gc/G_1575.png 1
#
# /gc/G_1576.png 1
#
# /gc/G_1577.png 1
#
# /gc/G_1578.png 1
#
# /gc/G_1579.png 1
#
# /gc/G_158.png 1
#
# /gc/G_1580.png 1
#
# /gc/G_1581.png 1
#
# /gc/G_1582.png 1
#
# /gc/G_1583.png 1
#
# /gc/G_1584.png 1
#
# /gc/G_1585.png 1
#
# /gc/G_1586.png 1
#
# /gc/G_1587.png 1
#
# /gc/G_1588.png 1
#
# /gc/G_1589.png 1
#
# /gc/G_159.png 1
#
# /gc/G_1590.png 1
#
# /gc/G_1591.png 1
#
# /gc/G_1592.png 1
#
# /gc/G_1593.png 1
#
# /gc/G_1594.png 1
#
# /gc/G_1595.png 1
#
# /gc/G_1596.png 1
#
# /gc/G_1597.png 1
#
# /gc/G_1598.png 1
#
# /gc/G_1599.png 1
#
# /gc/G_16.png 1
#
# /gc/G_160.png 1
#
# /gc/G_1600.png 1
#
# /gc/G_1601.png 1
#
# /gc/G_1602.png 1
#
# /gc/G_1603.png 1
#
# /gc/G_1604.png 1
#
# /gc/G_1605.png 1
#
# /gc/G_1606.png 1
#
# /gc/G_1607.png 1
#
# /gc/G_1608.png 1
#
# /gc/G_1609.png 1
#
# /gc/G_161.png 1
#
# /gc/G_1610.png 1
#
# /gc/G_1611.png 1
#
# /gc/G_1612.png 1
#
# /gc/G_1613.png 1
#
# /gc/G_1614.png 1
#
# /gc/G_1615.png 1
#
# /gc/G_1616.png 1
#
# /gc/G_1617.png 1
#
# /gc/G_1618.png 1
#
# /gc/G_1619.png 1
#
# /gc/G_162.png 1
#
# /gc/G_1620.png 1
#
# /gc/G_1621.png 1
#
# /gc/G_1622.png 1
#
# /gc/G_1623.png 1
#
# /gc/G_1624.png 1
#
# /gc/G_1625.png 1
#
# /gc/G_1626.png 1
#
# /gc/G_1627.png 1
#
# /gc/G_1628.png 1
#
# /gc/G_1629.png 1
#
# /gc/G_163.png 1
#
# /gc/G_1630.png 1
#
# /gc/G_1631.png 1
#
# /gc/G_1632.png 1
#
# /gc/G_1633.png 1
#
# /gc/G_1634.png 1
#
# /gc/G_1635.png 1
#
# /gc/G_1636.png 1
#
# /gc/G_1637.png 1
#
# /gc/G_1638.png 1
#
# /gc/G_1639.png 1
#
# /gc/G_164.png 1
#
# /gc/G_1640.png 1
#
# /gc/G_1641.png 1
#
# /gc/G_1642.png 1
#
# /gc/G_1643.png 1
#
# /gc/G_1644.png 1
#
# /gc/G_1645.png 1
#
# /gc/G_1646.png 1
#
# /gc/G_1647.png 1
#
# /gc/G_1648.png 1
#
# /gc/G_1649.png 1
#
# /gc/G_165.png 1
#
# /gc/G_1650.png 1
#
# /gc/G_1651.png 1
#
# /gc/G_1652.png 1
#
# /gc/G_1653.png 1
#
# /gc/G_1654.png 1
#
# /gc/G_1655.png 1
#
# /gc/G_1656.png 1
#
# /gc/G_1657.png 1
#
# /gc/G_1658.png 1
#
# /gc/G_1659.png 1
#
# /gc/G_166.png 1
#
# /gc/G_1660.png 1
#
# /gc/G_1661.png 1
#
# /gc/G_1662.png 1
#
# /gc/G_1663.png 1
#
# /gc/G_1664.png 1
#
# /gc/G_1665.png 1
#
# /gc/G_1666.png 1
#
# /gc/G_1667.png 1
#
# /gc/G_1668.png 1
#
# /gc/G_1669.png 1
#
# /gc/G_167.png 1
#
# /gc/G_1670.png 1
#
# /gc/G_1671.png 1
#
# /gc/G_1672.png 1
#
# /gc/G_1673.png 1
#
# /gc/G_1674.png 1
#
# /gc/G_1675.png 1
#
# /gc/G_1676.png 1
#
# /gc/G_1677.png 1
#
# /gc/G_1678.png 1
#
# /gc/G_1679.png 1
#
# /gc/G_168.png 1
#
# /gc/G_1680.png 1
#
# /gc/G_1681.png 1
#
# /gc/G_1682.png 1
#
# /gc/G_1683.png 1
#
# /gc/G_1684.png 1
#
# /gc/G_1685.png 1
#
# /gc/G_1686.png 1
#
# /gc/G_1687.png 1
#
# /gc/G_1688.png 1
#
# /gc/G_1689.png 1
#
# /gc/G_169.png 1
#
# /gc/G_1690.png 1
#
# /gc/G_1691.png 1
#
# /gc/G_1692.png 1
#
# /gc/G_1693.png 1
#
# /gc/G_1694.png 1
#
# /gc/G_1695.png 1
#
# /gc/G_1696.png 1
#
# /gc/G_1697.png 1
#
# /gc/G_1698.png 1
#
# /gc/G_1699.png 1
#
# /gc/G_17.png 1
#
# /gc/G_170.png 1
#
# /gc/G_1700.png 1
#
# /gc/G_1701.png 1
#
# /gc/G_1702.png 1
#
# /gc/G_1703.png 1
#
# /gc/G_1704.png 1
#
# /gc/G_1705.png 1
#
# /gc/G_1706.png 1
#
# /gc/G_1707.png 1
#
# /gc/G_1708.png 1
#
# /gc/G_1709.png 1
#
# /gc/G_171.png 1
#
# /gc/G_1710.png 1
#
# /gc/G_1711.png 1
#
# /gc/G_1712.png 1
#
# /gc/G_1713.png 1
#
# /gc/G_1714.png 1
#
# /gc/G_1715.png 1
#
# /gc/G_1716.png 1
#
# /gc/G_1717.png 1
#
# /gc/G_1718.png 1
#
# /gc/G_1719.png 1
#
# /gc/G_172.png 1
#
# /gc/G_1720.png 1
#
# /gc/G_1721.png 1
#
# /gc/G_1722.png 1
#
# /gc/G_1723.png 1
#
# /gc/G_1724.png 1
#
# /gc/G_1725.png 1
#
# /gc/G_1726.png 1
#
# /gc/G_1727.png 1
#
# /gc/G_1728.png 1
#
# /gc/G_1729.png 1
#
# /gc/G_173.png 1
#
# /gc/G_1730.png 1
#
# /gc/G_1731.png 1
#
# /gc/G_1732.png 1
#
# /gc/G_1733.png 1
#
# /gc/G_1734.png 1
#
# /gc/G_1735.png 1
#
# /gc/G_1736.png 1
#
# /gc/G_1737.png 1
#
# /gc/G_1738.png 1
#
# /gc/G_1739.png 1
#
# /gc/G_174.png 1
#
# /gc/G_1740.png 1
#
# /gc/G_1741.png 1
#
# /gc/G_1742.png 1
#
# /gc/G_1743.png 1
#
# /gc/G_1744.png 1
#
# /gc/G_1745.png 1
#
# /gc/G_1746.png 1
#
# /gc/G_1747.png 1
#
# /gc/G_1748.png 1
#
# /gc/G_1749.png 1
#
# /gc/G_175.png 1
#
# /gc/G_1750.png 1
#
# /gc/G_1751.png 1
#
# /gc/G_1752.png 1
#
# /gc/G_1753.png 1
#
# /gc/G_1754.png 1
#
# /gc/G_1755.png 1
#
# /gc/G_1756.png 1
#
# /gc/G_1757.png 1
#
# /gc/G_1758.png 1
#
# /gc/G_1759.png 1
#
# /gc/G_176.png 1
#
# /gc/G_1760.png 1
#
# /gc/G_1761.png 1
#
# /gc/G_1762.png 1
#
# /gc/G_1763.png 1
#
# /gc/G_1764.png 1
#
# /gc/G_1765.png 1
#
# /gc/G_1766.png 1
#
# /gc/G_1767.png 1
#
# /gc/G_1768.png 1
#
# /gc/G_1769.png 1
#
# /gc/G_177.png 1
#
# /gc/G_1770.png 1
#
# /gc/G_1771.png 1
#
# /gc/G_1772.png 1
#
# /gc/G_1773.png 1
#
# /gc/G_1774.png 1
#
# /gc/G_1775.png 1
#
# /gc/G_1776.png 1
#
# /gc/G_1777.png 1
#
# /gc/G_1778.png 1
#
# /gc/G_1779.png 1
#
# /gc/G_178.png 1
#
# /gc/G_1780.png 1
#
# /gc/G_1781.png 1
#
# /gc/G_1782.png 1
#
# /gc/G_1783.png 1
#
# /gc/G_1784.png 1
#
# /gc/G_1785.png 1
#
# /gc/G_1786.png 1
#
# /gc/G_1787.png 1
#
# /gc/G_1788.png 1
#
# /gc/G_1789.png 1
#
# /gc/G_179.png 1
#
# /gc/G_1790.png 1
#
# /gc/G_1791.png 1
#
# /gc/G_1792.png 1
#
# /gc/G_1793.png 1
#
# /gc/G_1794.png 1
#
# /gc/G_1795.png 1
#
# /gc/G_1796.png 1
#
# /gc/G_1797.png 1
#
# /gc/G_1798.png 1
#
# /gc/G_1799.png 1
#
# /gc/G_18.png 1
#
# /gc/G_180.png 1
#
# /gc/G_1800.png 1
#
# /gc/G_1801.png 1
#
# /gc/G_1802.png 1
#
# /gc/G_1803.png 1
#
# /gc/G_1804.png 1
#
# /gc/G_1805.png 1
#
# /gc/G_1806.png 1
#
# /gc/G_1807.png 1
#
# /gc/G_1808.png 1
#
# /gc/G_1809.png 1
#
# /gc/G_181.png 1
#
# /gc/G_1810.png 1
#
# /gc/G_1811.png 1
#
# /gc/G_1812.png 1
#
# /gc/G_1813.png 1
#
# /gc/G_1814.png 1
#
# /gc/G_1815.png 1
#
# /gc/G_1816.png 1
#
# /gc/G_1817.png 1
#
# /gc/G_1818.png 1
#
# /gc/G_1819.png 1
#
# /gc/G_182.png 1
#
# /gc/G_1820.png 1
#
# /gc/G_1821.png 1
#
# /gc/G_1822.png 1
#
# /gc/G_1823.png 1
#
# /gc/G_1824.png 1
#
# /gc/G_1825.png 1
#
# /gc/G_1826.png 1
#
# /gc/G_1827.png 1
#
# /gc/G_1828.png 1
#
# /gc/G_1829.png 1
#
# /gc/G_183.png 1
#
# /gc/G_1830.png 1
#
# /gc/G_1831.png 1
#
# /gc/G_1832.png 1
#
# /gc/G_1833.png 1
#
# /gc/G_1834.png 1
#
# /gc/G_1835.png 1
#
# /gc/G_1836.png 1
#
# /gc/G_1837.png 1
#
# /gc/G_1838.png 1
#
# /gc/G_1839.png 1
#
# /gc/G_184.png 1
#
# /gc/G_1840.png 1
#
# /gc/G_1841.png 1
#
# /gc/G_1842.png 1
#
# /gc/G_1843.png 1
#
# /gc/G_1844.png 1
#
# /gc/G_1845.png 1
#
# /gc/G_1846.png 1
#
# /gc/G_1847.png 1
#
# /gc/G_1848.png 1
#
# /gc/G_1849.png 1
#
# /gc/G_185.png 1
#
# /gc/G_1850.png 1
#
# /gc/G_1851.png 1
#
# /gc/G_1852.png 1
#
# /gc/G_1853.png 1
#
# /gc/G_1854.png 1
#
# /gc/G_1855.png 1
#
# /gc/G_1856.png 1
#
# /gc/G_1857.png 1
#
# /gc/G_1858.png 1
#
# /gc/G_1859.png 1
#
# /gc/G_186.png 1
#
# /gc/G_1860.png 1
#
# /gc/G_1861.png 1
#
# /gc/G_1862.png 1
#
# /gc/G_1863.png 1
#
# /gc/G_1864.png 1
#
# /gc/G_1865.png 1
#
# /gc/G_1866.png 1
#
# /gc/G_1867.png 1
#
# /gc/G_1868.png 1
#
# /gc/G_1869.png 1
#
# /gc/G_187.png 1
#
# /gc/G_1870.png 1
#
# /gc/G_1871.png 1
#
# /gc/G_1872.png 1
#
# /gc/G_1873.png 1
#
# /gc/G_1874.png 1
#
# /gc/G_1875.png 1
#
# /gc/G_1876.png 1
#
# /gc/G_1877.png 1
#
# /gc/G_1878.png 1
#
# /gc/G_1879.png 1
#
# /gc/G_188.png 1
#
# /gc/G_1880.png 1
#
# /gc/G_1881.png 1
#
# /gc/G_1882.png 1
#
# /gc/G_1883.png 1
#
# /gc/G_1884.png 1
#
# /gc/G_1885.png 1
#
# /gc/G_1886.png 1
#
# /gc/G_1887.png 1
#
# /gc/G_1888.png 1
#
# /gc/G_1889.png 1
#
# /gc/G_189.png 1
#
# /gc/G_1890.png 1
#
# /gc/G_1891.png 1
#
# /gc/G_1892.png 1
#
# /gc/G_1893.png 1
#
# /gc/G_1894.png 1
#
# /gc/G_1895.png 1
#
# /gc/G_1896.png 1
#
# /gc/G_1897.png 1
#
# /gc/G_1898.png 1
#
# /gc/G_1899.png 1
#
# /gc/G_19.png 1
#
# /gc/G_190.png 1
#
# /gc/G_1900.png 1
#
# /gc/G_1901.png 1
#
# /gc/G_1902.png 1
#
# /gc/G_1903.png 1
#
# /gc/G_1904.png 1
#
# /gc/G_1905.png 1
#
# /gc/G_1906.png 1
#
# /gc/G_1907.png 1
#
# /gc/G_1908.png 1
#
# /gc/G_1909.png 1
#
# /gc/G_191.png 1
#
# /gc/G_1910.png 1
#
# /gc/G_1911.png 1
#
# /gc/G_1912.png 1
#
# /gc/G_1913.png 1
#
# /gc/G_1914.png 1
#
# /gc/G_1915.png 1
#
# /gc/G_1916.png 1
#
# /gc/G_1917.png 1
#
# /gc/G_1918.png 1
#
# /gc/G_1919.png 1
#
# /gc/G_192.png 1
#
# /gc/G_1920.png 1
#
# /gc/G_1921.png 1
#
# /gc/G_1922.png 1
#
# /gc/G_1923.png 1
#
# /gc/G_1924.png 1
#
# /gc/G_1925.png 1
#
# /gc/G_1926.png 1
#
# /gc/G_1927.png 1
#
# /gc/G_1928.png 1
#
# /gc/G_1929.png 1
#
# /gc/G_193.png 1
#
# /gc/G_1930.png 1
#
# /gc/G_1931.png 1
#
# /gc/G_1932.png 1
#
# /gc/G_1933.png 1
#
# /gc/G_1934.png 1
#
# /gc/G_1935.png 1
#
# /gc/G_1936.png 1
#
# /gc/G_1937.png 1
#
# /gc/G_1938.png 1
#
# /gc/G_1939.png 1
#
# /gc/G_194.png 1
#
# /gc/G_1940.png 1
#
# /gc/G_1941.png 1
#
# /gc/G_1942.png 1
#
# /gc/G_1943.png 1
#
# /gc/G_1944.png 1
#
# /gc/G_1945.png 1
#
# /gc/G_1946.png 1
#
# /gc/G_1947.png 1
#
# /gc/G_1948.png 1
#
# /gc/G_1949.png 1
#
# /gc/G_195.png 1
#
# /gc/G_1950.png 1
#
# /gc/G_1951.png 1
#
# /gc/G_1952.png 1
#
# /gc/G_1953.png 1
#
# /gc/G_1954.png 1
#
# /gc/G_1955.png 1
#
# /gc/G_1956.png 1
#
# /gc/G_1957.png 1
#
# /gc/G_1958.png 1
#
# /gc/G_1959.png 1
#
# /gc/G_196.png 1
#
# /gc/G_1960.png 1
#
# /gc/G_1961.png 1
#
# /gc/G_1962.png 1
#
# /gc/G_1963.png 1
#
# /gc/G_1964.png 1
#
# /gc/G_1965.png 1
#
# /gc/G_1966.png 1
#
# /gc/G_1967.png 1
#
# /gc/G_1968.png 1
#
# /gc/G_1969.png 1
#
# /gc/G_197.png 1
#
# /gc/G_1970.png 1
#
# /gc/G_1971.png 1
#
# /gc/G_1972.png 1
#
# /gc/G_1973.png 1
#
# /gc/G_1974.png 1
#
# /gc/G_1975.png 1
#
# /gc/G_1976.png 1
#
# /gc/G_1977.png 1
#
# /gc/G_1978.png 1
#
# /gc/G_1979.png 1
#
# /gc/G_198.png 1
#
# /gc/G_1980.png 1
#
# /gc/G_1981.png 1
#
# /gc/G_1982.png 1
#
# /gc/G_1983.png 1
#
# /gc/G_1984.png 1
#
# /gc/G_1985.png 1
#
# /gc/G_1986.png 1
#
# /gc/G_1987.png 1
#
# /gc/G_1988.png 1
#
# /gc/G_1989.png 1
#
# /gc/G_199.png 1
#
# /gc/G_1990.png 1
#
# /gc/G_1991.png 1
#
# /gc/G_1992.png 1
#
# /gc/G_1993.png 1
#
# /gc/G_1994.png 1
#
# /gc/G_1995.png 1
#
# /gc/G_1996.png 1
#
# /gc/G_1997.png 1
#
# /gc/G_1998.png 1
#
# /gc/G_1999.png 1
#
# /gc/G_2.png 1
#
# /gc/G_20.png 1
#
# /gc/G_200.png 1
#
# /gc/G_2000.png 1
#
# /gc/G_2001.png 1
#
# /gc/G_2002.png 1
#
# /gc/G_2003.png 1
#
# /gc/G_2004.png 1
#
# /gc/G_2005.png 1
#
# /gc/G_2006.png 1
#
# /gc/G_2007.png 1
#
# /gc/G_2008.png 1
#
# /gc/G_2009.png 1
#
# /gc/G_201.png 1
#
# /gc/G_2010.png 1
#
# /gc/G_2011.png 1
#
# /gc/G_2012.png 1
#
# /gc/G_2013.png 1
#
# /gc/G_2014.png 1
#
# /gc/G_2015.png 1
#
# /gc/G_2016.png 1
#
# /gc/G_2017.png 1
#
# /gc/G_2018.png 1
#
# /gc/G_2019.png 1
#
# /gc/G_202.png 1
#
# /gc/G_2020.png 1
#
# /gc/G_2021.png 1
#
# /gc/G_2022.png 1
#
# /gc/G_2023.png 1
#
# /gc/G_2024.png 1
#
# /gc/G_2025.png 1
#
# /gc/G_2026.png 1
#
# /gc/G_2027.png 1
#
# /gc/G_2028.png 1
#
# /gc/G_2029.png 1
#
# /gc/G_203.png 1
#
# /gc/G_2030.png 1
#
# /gc/G_2031.png 1
#
# /gc/G_2032.png 1
#
# /gc/G_2033.png 1
#
# /gc/G_2034.png 1
#
# /gc/G_2035.png 1
#
# /gc/G_2036.png 1
#
# /gc/G_2037.png 1
#
# /gc/G_2038.png 1
#
# /gc/G_2039.png 1
#
# /gc/G_204.png 1
#
# /gc/G_2040.png 1
#
# /gc/G_2041.png 1
#
# /gc/G_2042.png 1
#
# /gc/G_2043.png 1
#
# /gc/G_2044.png 1
#
# /gc/G_2045.png 1
#
# /gc/G_2046.png 1
#
# /gc/G_2047.png 1
#
# /gc/G_2048.png 1
#
# /gc/G_2049.png 1
#
# /gc/G_205.png 1
#
# /gc/G_2050.png 1
#
# /gc/G_2051.png 1
#
# /gc/G_2052.png 1
#
# /gc/G_2053.png 1
#
# /gc/G_2054.png 1
#
# /gc/G_2055.png 1
#
# /gc/G_2056.png 1
#
# /gc/G_2057.png 1
#
# /gc/G_2058.png 1
#
# /gc/G_2059.png 1
#
# /gc/G_206.png 1
#
# /gc/G_2060.png 1
#
# /gc/G_2061.png 1
#
# /gc/G_2062.png 1
#
# /gc/G_2063.png 1
#
# /gc/G_2064.png 1
#
# /gc/G_2065.png 1
#
# /gc/G_2066.png 1
#
# /gc/G_2067.png 1
#
# /gc/G_2068.png 1
#
# /gc/G_2069.png 1
#
# /gc/G_207.png 1
#
# /gc/G_2070.png 1
#
# /gc/G_2071.png 1
#
# /gc/G_2072.png 1
#
# /gc/G_2073.png 1
#
# /gc/G_2074.png 1
#
# /gc/G_2075.png 1
#
# /gc/G_2076.png 1
#
# /gc/G_2077.png 1
#
# /gc/G_2078.png 1
#
# /gc/G_2079.png 1
#
# /gc/G_208.png 1
#
# /gc/G_2080.png 1
#
# /gc/G_2081.png 1
#
# /gc/G_2082.png 1
#
# /gc/G_2083.png 1
#
# /gc/G_2084.png 1
#
# /gc/G_2085.png 1
#
# /gc/G_2086.png 1
#
# /gc/G_2087.png 1
#
# /gc/G_2088.png 1
#
# /gc/G_2089.png 1
#
# /gc/G_209.png 1
#
# /gc/G_2090.png 1
#
# /gc/G_2091.png 1
#
# /gc/G_2092.png 1
#
# /gc/G_2093.png 1
#
# /gc/G_2094.png 1
#
# /gc/G_2095.png 1
#
# /gc/G_2096.png 1
#
# /gc/G_2097.png 1
#
# /gc/G_2098.png 1
#
# /gc/G_2099.png 1
#
# /gc/G_21.png 1
#
# /gc/G_210.png 1
#
# /gc/G_2100.png 1
#
# /gc/G_2101.png 1
#
# /gc/G_2102.png 1
#
# /gc/G_2103.png 1
#
# /gc/G_2104.png 1
#
# /gc/G_2105.png 1
#
# /gc/G_2106.png 1
#
# /gc/G_2107.png 1
#
# /gc/G_2108.png 1
#
# /gc/G_2109.png 1
#
# /gc/G_211.png 1
#
# /gc/G_2110.png 1
#
# /gc/G_2111.png 1
#
# /gc/G_2112.png 1
#
# /gc/G_2113.png 1
#
# /gc/G_2114.png 1
#
# /gc/G_2115.png 1
#
# /gc/G_2116.png 1
#
# /gc/G_2117.png 1
#
# /gc/G_2118.png 1
#
# /gc/G_2119.png 1
#
# /gc/G_212.png 1
#
# /gc/G_2120.png 1
#
# /gc/G_2121.png 1
#
# /gc/G_2122.png 1
#
# /gc/G_2123.png 1
#
# /gc/G_2124.png 1
#
# /gc/G_2125.png 1
#
# /gc/G_2126.png 1
#
# /gc/G_2127.png 1
#
# /gc/G_2128.png 1
#
# /gc/G_2129.png 1
#
# /gc/G_213.png 1
#
# /gc/G_2130.png 1
#
# /gc/G_2131.png 1
#
# /gc/G_2132.png 1
#
# /gc/G_2133.png 1
#
# /gc/G_2134.png 1
#
# /gc/G_2135.png 1
#
# /gc/G_2136.png 1
#
# /gc/G_2137.png 1
#
# /gc/G_2138.png 1
#
# /gc/G_2139.png 1
#
# /gc/G_214.png 1
#
# /gc/G_2140.png 1
#
# /gc/G_2141.png 1
#
# /gc/G_2142.png 1
#
# /gc/G_2143.png 1
#
# /gc/G_2144.png 1
#
# /gc/G_2145.png 1
#
# /gc/G_2146.png 1
#
# /gc/G_2147.png 1
#
# /gc/G_2148.png 1
#
# /gc/G_2149.png 1
#
# /gc/G_215.png 1
#
# /gc/G_2150.png 1
#
# /gc/G_2151.png 1
#
# /gc/G_2152.png 1
#
# /gc/G_2153.png 1
#
# /gc/G_2154.png 1
#
# /gc/G_2155.png 1
#
# /gc/G_2156.png 1
#
# /gc/G_2157.png 1
#
# /gc/G_2158.png 1
#
# /gc/G_2159.png 1
#
# /gc/G_216.png 1
#
# /gc/G_2160.png 1
#
# /gc/G_2161.png 1
#
# /gc/G_2162.png 1
#
# /gc/G_2163.png 1
#
# /gc/G_2164.png 1
#
# /gc/G_2165.png 1
#
# /gc/G_2166.png 1
#
# /gc/G_2167.png 1
#
# /gc/G_2168.png 1
#
# /gc/G_2169.png 1
#
# /gc/G_217.png 1
#
# /gc/G_2170.png 1
#
# /gc/G_2171.png 1
#
# /gc/G_2172.png 1
#
# /gc/G_2173.png 1
#
# /gc/G_2174.png 1
#
# /gc/G_2175.png 1
#
# /gc/G_2176.png 1
#
# /gc/G_2177.png 1
#
# /gc/G_2178.png 1
#
# /gc/G_2179.png 1
#
# /gc/G_218.png 1
#
# /gc/G_2180.png 1
#
# /gc/G_2181.png 1
#
# /gc/G_2182.png 1
#
# /gc/G_2183.png 1
#
# /gc/G_2184.png 1
#
# /gc/G_2185.png 1
#
# /gc/G_2186.png 1
#
# /gc/G_2187.png 1
#
# /gc/G_2188.png 1
#
# /gc/G_2189.png 1
#
# /gc/G_219.png 1
#
# /gc/G_2190.png 1
#
# /gc/G_2191.png 1
#
# /gc/G_2192.png 1
#
# /gc/G_2193.png 1
#
# /gc/G_2194.png 1
#
# /gc/G_2195.png 1
#
# /gc/G_2196.png 1
#
# /gc/G_2197.png 1
#
# /gc/G_2198.png 1
#
# /gc/G_2199.png 1
#
# /gc/G_22.png 1
#
# /gc/G_220.png 1
#
# /gc/G_2200.png 1
#
# /gc/G_2201.png 1
#
# /gc/G_2202.png 1
#
# /gc/G_2203.png 1
#
# /gc/G_2204.png 1
#
# /gc/G_2205.png 1
#
# /gc/G_2206.png 1
#
# /gc/G_2207.png 1
#
# /gc/G_2208.png 1
#
# /gc/G_2209.png 1
#
# /gc/G_221.png 1
#
# /gc/G_2210.png 1
#
# /gc/G_2211.png 1
#
# /gc/G_2212.png 1
#
# /gc/G_2213.png 1
#
# /gc/G_2214.png 1
#
# /gc/G_2215.png 1
#
# /gc/G_2216.png 1
#
# /gc/G_2217.png 1
#
# /gc/G_2218.png 1
#
# /gc/G_2219.png 1
#
# /gc/G_222.png 1
#
# /gc/G_2220.png 1
#
# /gc/G_2221.png 1
#
# /gc/G_2222.png 1
#
# /gc/G_2223.png 1
#
# /gc/G_2224.png 1
#
# /gc/G_2225.png 1
#
# /gc/G_2226.png 1
#
# /gc/G_2227.png 1
#
# /gc/G_2228.png 1
#
# /gc/G_2229.png 1
#
# /gc/G_223.png 1
#
# /gc/G_2230.png 1
#
# /gc/G_2231.png 1
#
# /gc/G_2232.png 1
#
# /gc/G_2233.png 1
#
# /gc/G_2234.png 1
#
# /gc/G_2235.png 1
#
# /gc/G_2236.png 1
#
# /gc/G_2237.png 1
#
# /gc/G_2238.png 1
#
# /gc/G_2239.png 1
#
# /gc/G_224.png 1
#
# /gc/G_2240.png 1
#
# /gc/G_2241.png 1
#
# /gc/G_2242.png 1
#
# /gc/G_2243.png 1
#
# /gc/G_2244.png 1
#
# /gc/G_2245.png 1
#
# /gc/G_2246.png 1
#
# /gc/G_2247.png 1
#
# /gc/G_2248.png 1
#
# /gc/G_2249.png 1
#
# /gc/G_225.png 1
#
# /gc/G_2250.png 1
#
# /gc/G_2251.png 1
#
# /gc/G_2252.png 1
#
# /gc/G_2253.png 1
#
# /gc/G_2254.png 1
#
# /gc/G_2255.png 1
#
# /gc/G_2256.png 1
#
# /gc/G_2257.png 1
#
# /gc/G_2258.png 1
#
# /gc/G_2259.png 1
#
# /gc/G_226.png 1
#
# /gc/G_2260.png 1
#
# /gc/G_2261.png 1
#
# /gc/G_2262.png 1
#
# /gc/G_2263.png 1
#
# /gc/G_2264.png 1
#
# /gc/G_2265.png 1
#
# /gc/G_2266.png 1
#
# /gc/G_2267.png 1
#
# /gc/G_2268.png 1
#
# /gc/G_2269.png 1
#
# /gc/G_227.png 1
#
# /gc/G_2270.png 1
#
# /gc/G_2271.png 1
#
# /gc/G_2272.png 1
#
# /gc/G_2273.png 1
#
# /gc/G_2274.png 1
#
# /gc/G_2275.png 1
#
# /gc/G_2276.png 1
#
# /gc/G_2277.png 1
#
# /gc/G_2278.png 1
#
# /gc/G_2279.png 1
#
# /gc/G_228.png 1
#
# /gc/G_2280.png 1
#
# /gc/G_2281.png 1
#
# /gc/G_2282.png 1
#
# /gc/G_2283.png 1
#
# /gc/G_2284.png 1
#
# /gc/G_2285.png 1
#
# /gc/G_2286.png 1
#
# /gc/G_2287.png 1
#
# /gc/G_2288.png 1
#
# /gc/G_2289.png 1
#
# /gc/G_229.png 1
#
# /gc/G_2290.png 1
#
# /gc/G_2291.png 1
#
# /gc/G_2292.png 1
#
# /gc/G_2293.png 1
#
# /gc/G_2294.png 1
#
# /gc/G_2295.png 1
#
# /gc/G_2296.png 1
#
# /gc/G_2297.png 1
#
# /gc/G_2298.png 1
#
# /gc/G_2299.png 1
#
# /gc/G_23.png 1
#
# /gc/G_230.png 1
#
# /gc/G_2300.png 1
#
# /gc/G_2301.png 1
#
# /gc/G_2302.png 1
#
# /gc/G_2303.png 1
#
# /gc/G_2304.png 1
#
# /gc/G_2305.png 1
#
# /gc/G_2306.png 1
#
# /gc/G_2307.png 1
#
# /gc/G_2308.png 1
#
# /gc/G_2309.png 1
#
# /gc/G_231.png 1
#
# /gc/G_2310.png 1
#
# /gc/G_2311.png 1
#
# /gc/G_2312.png 1
#
# /gc/G_2313.png 1
#
# /gc/G_2314.png 1
#
# /gc/G_2315.png 1
#
# /gc/G_2316.png 1
#
# /gc/G_2317.png 1
#
# /gc/G_2318.png 1
#
# /gc/G_2319.png 1
#
# /gc/G_232.png 1
#
# /gc/G_2320.png 1
#
# /gc/G_2321.png 1
#
# /gc/G_2322.png 1
#
# /gc/G_2323.png 1
#
# /gc/G_2324.png 1
#
# /gc/G_2325.png 1
#
# /gc/G_2326.png 1
#
# /gc/G_2327.png 1
#
# /gc/G_2328.png 1
#
# /gc/G_2329.png 1
#
# /gc/G_233.png 1
#
# /gc/G_2330.png 1
#
# /gc/G_2331.png 1
#
# /gc/G_2332.png 1
#
# /gc/G_2333.png 1
#
# /gc/G_2334.png 1
#
# /gc/G_2335.png 1
#
# /gc/G_2336.png 1
#
# /gc/G_2337.png 1
#
# /gc/G_2338.png 1
#
# /gc/G_2339.png 1
#
# /gc/G_234.png 1
#
# /gc/G_2340.png 1
#
# /gc/G_2341.png 1
#
# /gc/G_2342.png 1
#
# /gc/G_2343.png 1
#
# /gc/G_2344.png 1
#
# /gc/G_2345.png 1
#
# /gc/G_2346.png 1
#
# /gc/G_2347.png 1
#
# /gc/G_2348.png 1
#
# /gc/G_2349.png 1
#
# /gc/G_235.png 1
#
# /gc/G_2350.png 1
#
# /gc/G_2351.png 1
#
# /gc/G_2352.png 1
#
# /gc/G_2353.png 1
#
# /gc/G_2354.png 1
#
# /gc/G_2355.png 1
#
# /gc/G_2356.png 1
#
# /gc/G_2357.png 1
#
# /gc/G_2358.png 1
#
# /gc/G_2359.png 1
#
# /gc/G_236.png 1
#
# /gc/G_2360.png 1
#
# /gc/G_2361.png 1
#
# /gc/G_2362.png 1
#
# /gc/G_2363.png 1
#
# /gc/G_2364.png 1
#
# /gc/G_2365.png 1
#
# /gc/G_2366.png 1
#
# /gc/G_2367.png 1
#
# /gc/G_2368.png 1
#
# /gc/G_2369.png 1
#
# /gc/G_237.png 1
#
# /gc/G_2370.png 1
#
# /gc/G_2371.png 1
#
# /gc/G_2372.png 1
#
# /gc/G_2373.png 1
#
# /gc/G_2374.png 1
#
# /gc/G_2375.png 1
#
# /gc/G_2376.png 1
#
# /gc/G_2377.png 1
#
# /gc/G_2378.png 1
#
# /gc/G_2379.png 1
#
# /gc/G_238.png 1
#
# /gc/G_2380.png 1
#
# /gc/G_2381.png 1
#
# /gc/G_2382.png 1
#
# /gc/G_2383.png 1
#
# /gc/G_2384.png 1
#
# /gc/G_2385.png 1
#
# /gc/G_2386.png 1
#
# /gc/G_2387.png 1
#
# /gc/G_2388.png 1
#
# /gc/G_2389.png 1
#
# /gc/G_239.png 1
#
# /gc/G_2390.png 1
#
# /gc/G_2391.png 1
#
# /gc/G_2392.png 1
#
# /gc/G_2393.png 1
#
# /gc/G_2394.png 1
#
# /gc/G_2395.png 1
#
# /gc/G_2396.png 1
#
# /gc/G_2397.png 1
#
# /gc/G_2398.png 1
#
# /gc/G_2399.png 1
#
# /gc/G_24.png 1
#
# /gc/G_240.png 1
#
# /gc/G_2400.png 1
#
# /gc/G_2401.png 1
#
# /gc/G_2402.png 1
#
# /gc/G_2403.png 1
#
# /gc/G_2404.png 1
#
# /gc/G_2405.png 1
#
# /gc/G_2406.png 1
#
# /gc/G_2407.png 1
#
# /gc/G_2408.png 1
#
# /gc/G_2409.png 1
#
# /gc/G_241.png 1
#
# /gc/G_2410.png 1
#
# /gc/G_2411.png 1
#
# /gc/G_2412.png 1
#
# /gc/G_2413.png 1
#
# /gc/G_2414.png 1
#
# /gc/G_2415.png 1
#
# /gc/G_2416.png 1
#
# /gc/G_2417.png 1
#
# /gc/G_2418.png 1
#
# /gc/G_2419.png 1
#
# /gc/G_242.png 1
#
# /gc/G_2420.png 1
#
# /gc/G_2421.png 1
#
# /gc/G_2422.png 1
#
# /gc/G_2423.png 1
#
# /gc/G_2424.png 1
#
# /gc/G_2425.png 1
#
# /gc/G_2426.png 1
#
# /gc/G_2427.png 1
#
# /gc/G_2428.png 1
#
# /gc/G_2429.png 1
#
# /gc/G_243.png 1
#
# /gc/G_2430.png 1
#
# /gc/G_2431.png 1
#
# /gc/G_2432.png 1
#
# /gc/G_2433.png 1
#
# /gc/G_2434.png 1
#
# /gc/G_2435.png 1
#
# /gc/G_2436.png 1
#
# /gc/G_2437.png 1
#
# /gc/G_2438.png 1
#
# /gc/G_2439.png 1
#
# /gc/G_244.png 1
#
# /gc/G_2440.png 1
#
# /gc/G_2441.png 1
#
# /gc/G_2442.png 1
#
# /gc/G_2443.png 1
#
# /gc/G_2444.png 1
#
# /gc/G_2445.png 1
#
# /gc/G_2446.png 1
#
# /gc/G_2447.png 1
#
# /gc/G_2448.png 1
#
# /gc/G_2449.png 1
#
# /gc/G_245.png 1
#
# /gc/G_2450.png 1
#
# /gc/G_2451.png 1
#
# /gc/G_2452.png 1
#
# /gc/G_2453.png 1
#
# /gc/G_2454.png 1
#
# /gc/G_2455.png 1
#
# /gc/G_2456.png 1
#
# /gc/G_2457.png 1
#
# /gc/G_2458.png 1
#
# /gc/G_2459.png 1
#
# /gc/G_246.png 1
#
# /gc/G_2460.png 1
#
# /gc/G_2461.png 1
#
# /gc/G_2462.png 1
#
# /gc/G_2463.png 1
#
# /gc/G_2464.png 1
#
# /gc/G_2465.png 1
#
# /gc/G_2466.png 1
#
# /gc/G_2467.png 1
#
# /gc/G_2468.png 1
#
# /gc/G_2469.png 1
#
# /gc/G_247.png 1
#
# /gc/G_2470.png 1
#
# /gc/G_2471.png 1
#
# /gc/G_2472.png 1
#
# /gc/G_2473.png 1
#
# /gc/G_2474.png 1
#
# /gc/G_2475.png 1
#
# /gc/G_2476.png 1
#
# /gc/G_2477.png 1
#
# /gc/G_2478.png 1
#
# /gc/G_2479.png 1
#
# /gc/G_248.png 1
#
# /gc/G_2480.png 1
#
# /gc/G_2481.png 1
#
# /gc/G_2482.png 1
#
# /gc/G_2483.png 1
#
# /gc/G_2484.png 1
#
# /gc/G_2485.png 1
#
# /gc/G_2486.png 1
#
# /gc/G_2487.png 1
#
# /gc/G_2488.png 1
#
# /gc/G_2489.png 1
#
# /gc/G_249.png 1
#
# /gc/G_2490.png 1
#
# /gc/G_2491.png 1
#
# /gc/G_2492.png 1
#
# /gc/G_2493.png 1
#
# /gc/G_2494.png 1
#
# /gc/G_2495.png 1
#
# /gc/G_2496.png 1
#
# /gc/G_2497.png 1
#
# /gc/G_2498.png 1
#
# /gc/G_2499.png 1
#
# /gc/G_25.png 1
#
# /gc/G_250.png 1
#
# /gc/G_2500.png 1
#
# /gc/G_2501.png 1
#
# /gc/G_2502.png 1
#
# /gc/G_2503.png 1
#
# /gc/G_2504.png 1
#
# /gc/G_2505.png 1
#
# /gc/G_2506.png 1
#
# /gc/G_2507.png 1
#
# /gc/G_2508.png 1
#
# /gc/G_2509.png 1
#
# /gc/G_251.png 1
#
# /gc/G_2510.png 1
#
# /gc/G_2511.png 1
#
# /gc/G_2512.png 1
#
# /gc/G_2513.png 1
#
# /gc/G_2514.png 1
#
# /gc/G_2515.png 1
#
# /gc/G_2516.png 1
#
# /gc/G_2517.png 1
#
# /gc/G_2518.png 1
#
# /gc/G_2519.png 1
#
# /gc/G_252.png 1
#
# /gc/G_2520.png 1
#
# /gc/G_2521.png 1
#
# /gc/G_2522.png 1
#
# /gc/G_2523.png 1
#
# /gc/G_2524.png 1
#
# /gc/G_2525.png 1
#
# /gc/G_2526.png 1
#
# /gc/G_2527.png 1
#
# /gc/G_2528.png 1
#
# /gc/G_2529.png 1
#
# /gc/G_253.png 1
#
# /gc/G_2530.png 1
#
# /gc/G_2531.png 1
#
# /gc/G_2532.png 1
#
# /gc/G_2533.png 1
#
# /gc/G_2534.png 1
#
# /gc/G_2535.png 1
#
# /gc/G_2536.png 1
#
# /gc/G_2537.png 1
#
# /gc/G_2538.png 1
#
# /gc/G_2539.png 1
#
# /gc/G_254.png 1
#
# /gc/G_2540.png 1
#
# /gc/G_2541.png 1
#
# /gc/G_2542.png 1
#
# /gc/G_2543.png 1
#
# /gc/G_2544.png 1
#
# /gc/G_2545.png 1
#
# /gc/G_2546.png 1
#
# /gc/G_2547.png 1
#
# /gc/G_2548.png 1
#
# /gc/G_2549.png 1
#
# /gc/G_255.png 1
#
# /gc/G_2550.png 1
#
# /gc/G_2551.png 1
#
# /gc/G_2552.png 1
#
# /gc/G_2553.png 1
#
# /gc/G_2554.png 1
#
# /gc/G_2555.png 1
#
# /gc/G_2556.png 1
#
# /gc/G_2557.png 1
#
# /gc/G_2558.png 1
#
# /gc/G_2559.png 1
#
# /gc/G_256.png 1
#
# /gc/G_2560.png 1
#
# /gc/G_2561.png 1
#
# /gc/G_2562.png 1
#
# /gc/G_2563.png 1
#
# /gc/G_2564.png 1
#
# /gc/G_2565.png 1
#
# /gc/G_2566.png 1
#
# /gc/G_2567.png 1
#
# /gc/G_2568.png 1
#
# /gc/G_2569.png 1
#
# /gc/G_257.png 1
#
# /gc/G_2570.png 1
#
# /gc/G_2571.png 1
#
# /gc/G_2572.png 1
#
# /gc/G_2573.png 1
#
# /gc/G_2574.png 1
#
# /gc/G_2575.png 1
#
# /gc/G_2576.png 1
#
# /gc/G_2577.png 1
#
# /gc/G_2578.png 1
#
# /gc/G_2579.png 1
#
# /gc/G_258.png 1
#
# /gc/G_2580.png 1
#
# /gc/G_2581.png 1
#
# /gc/G_2582.png 1
#
# /gc/G_2583.png 1
#
# /gc/G_2584.png 1
#
# /gc/G_2585.png 1
#
# /gc/G_2586.png 1
#
# /gc/G_2587.png 1
#
# /gc/G_2588.png 1
#
# /gc/G_2589.png 1
#
# /gc/G_259.png 1
#
# /gc/G_2590.png 1
#
# /gc/G_2591.png 1
#
# /gc/G_2592.png 1
#
# /gc/G_2593.png 1
#
# /gc/G_2594.png 1
#
# /gc/G_2595.png 1
#
# /gc/G_2596.png 1
#
# /gc/G_2597.png 1
#
# /gc/G_2598.png 1
#
# /gc/G_2599.png 1
#
# /gc/G_26.png 1
#
# /gc/G_260.png 1
#
# /gc/G_2600.png 1
#
# /gc/G_2601.png 1
#
# /gc/G_2602.png 1
#
# /gc/G_2603.png 1
#
# /gc/G_2604.png 1
#
# /gc/G_2605.png 1
#
# /gc/G_2606.png 1
#
# /gc/G_2607.png 1
#
# /gc/G_2608.png 1
#
# /gc/G_2609.png 1
#
# /gc/G_261.png 1
#
# /gc/G_2610.png 1
#
# /gc/G_2611.png 1
#
# /gc/G_2612.png 1
#
# /gc/G_2613.png 1
#
# /gc/G_2614.png 1
#
# /gc/G_2615.png 1
#
# /gc/G_2616.png 1
#
# /gc/G_2617.png 1
#
# /gc/G_2618.png 1
#
# /gc/G_2619.png 1
#
# /gc/G_262.png 1
#
# /gc/G_2620.png 1
#
# /gc/G_2621.png 1
#
# /gc/G_2622.png 1
#
# /gc/G_2623.png 1
#
# /gc/G_2624.png 1
#
# /gc/G_2625.png 1
#
# /gc/G_2626.png 1
#
# /gc/G_2627.png 1
#
# /gc/G_2628.png 1
#
# /gc/G_2629.png 1
#
# /gc/G_263.png 1
#
# /gc/G_2630.png 1
#
# /gc/G_2631.png 1
#
# /gc/G_2632.png 1
#
# /gc/G_2633.png 1
#
# /gc/G_2634.png 1
#
# /gc/G_2635.png 1
#
# /gc/G_2636.png 1
#
# /gc/G_2637.png 1
#
# /gc/G_2638.png 1
#
# /gc/G_264.png 1
#
# /gc/G_265.png 1
#
# /gc/G_266.png 1
#
# /gc/G_267.png 1
#
# /gc/G_268.png 1
#
# /gc/G_269.png 1
#
# /gc/G_27.png 1
#
# /gc/G_270.png 1
#
# /gc/G_271.png 1
#
# /gc/G_272.png 1
#
# /gc/G_273.png 1
#
# /gc/G_274.png 1
#
# /gc/G_275.png 1
#
# /gc/G_276.png 1
#
# /gc/G_277.png 1
#
# /gc/G_278.png 1
#
# /gc/G_279.png 1
#
# /gc/G_28.png 1
#
# /gc/G_280.png 1
#
# /gc/G_281.png 1
#
# /gc/G_282.png 1
#
# /gc/G_283.png 1
#
# /gc/G_284.png 1
#
# /gc/G_285.png 1
#
# /gc/G_286.png 1
#
# /gc/G_287.png 1
#
# /gc/G_288.png 1
#
# /gc/G_289.png 1
#
# /gc/G_29.png 1
#
# /gc/G_290.png 1
#
# /gc/G_291.png 1
#
# /gc/G_292.png 1
#
# /gc/G_293.png 1
#
# /gc/G_294.png 1
#
# /gc/G_295.png 1
#
# /gc/G_296.png 1
#
# /gc/G_297.png 1
#
# /gc/G_298.png 1
#
# /gc/G_299.png 1
#
# /gc/G_3.png 1
#
# /gc/G_30.png 1
#
# /gc/G_300.png 1
#
# /gc/G_301.png 1
#
# /gc/G_302.png 1
#
# /gc/G_303.png 1
#
# /gc/G_304.png 1
#
# /gc/G_305.png 1
#
# /gc/G_306.png 1
#
# /gc/G_307.png 1
#
# /gc/G_308.png 1
#
# /gc/G_309.png 1
#
# /gc/G_31.png 1
#
# /gc/G_310.png 1
#
# /gc/G_311.png 1
#
# /gc/G_312.png 1
#
# /gc/G_313.png 1
#
# /gc/G_314.png 1
#
# /gc/G_315.png 1
#
# /gc/G_316.png 1
#
# /gc/G_317.png 1
#
# /gc/G_318.png 1
#
# /gc/G_319.png 1
#
# /gc/G_32.png 1
#
# /gc/G_320.png 1
#
# /gc/G_321.png 1
#
# /gc/G_322.png 1
#
# /gc/G_323.png 1
#
# /gc/G_324.png 1
#
# /gc/G_325.png 1
#
# /gc/G_326.png 1
#
# /gc/G_327.png 1
#
# /gc/G_328.png 1
#
# /gc/G_329.png 1
#
# /gc/G_33.png 1
#
# /gc/G_330.png 1
#
# /gc/G_331.png 1
#
# /gc/G_332.png 1
#
# /gc/G_333.png 1
#
# /gc/G_334.png 1
#
# /gc/G_335.png 1
#
# /gc/G_336.png 1
#
# /gc/G_337.png 1
#
# /gc/G_338.png 1
#
# /gc/G_339.png 1
#
# /gc/G_34.png 1
#
# /gc/G_340.png 1
#
# /gc/G_341.png 1
#
# /gc/G_342.png 1
#
# /gc/G_343.png 1
#
# /gc/G_344.png 1
#
# /gc/G_345.png 1
#
# /gc/G_346.png 1
#
# /gc/G_347.png 1
#
# /gc/G_348.png 1
#
# /gc/G_349.png 1
#
# /gc/G_35.png 1
#
# /gc/G_350.png 1
#
# /gc/G_351.png 1
#
# /gc/G_352.png 1
#
# /gc/G_353.png 1
#
# /gc/G_354.png 1
#
# /gc/G_355.png 1
#
# /gc/G_356.png 1
#
# /gc/G_357.png 1
#
# /gc/G_358.png 1
#
# /gc/G_359.png 1
#
# /gc/G_36.png 1
#
# /gc/G_360.png 1
#
# /gc/G_361.png 1
#
# /gc/G_362.png 1
#
# /gc/G_363.png 1
#
# /gc/G_364.png 1
#
# /gc/G_365.png 1
#
# /gc/G_366.png 1
#
# /gc/G_367.png 1
#
# /gc/G_368.png 1
#
# /gc/G_369.png 1
#
# /gc/G_37.png 1
#
# /gc/G_370.png 1
#
# /gc/G_371.png 1
#
# /gc/G_372.png 1
#
# /gc/G_373.png 1
#
# /gc/G_374.png 1
#
# /gc/G_375.png 1
#
# /gc/G_376.png 1
#
# /gc/G_377.png 1
#
# /gc/G_378.png 1
#
# /gc/G_379.png 1
#
# /gc/G_38.png 1
#
# /gc/G_380.png 1
#
# /gc/G_381.png 1
#
# /gc/G_382.png 1
#
# /gc/G_383.png 1
#
# /gc/G_384.png 1
#
# /gc/G_385.png 1
#
# /gc/G_386.png 1
#
# /gc/G_387.png 1
#
# /gc/G_388.png 1
#
# /gc/G_389.png 1
#
# /gc/G_39.png 1
#
# /gc/G_390.png 1
#
# /gc/G_391.png 1
#
# /gc/G_392.png 1
#
# /gc/G_393.png 1
#
# /gc/G_394.png 1
#
# /gc/G_395.png 1
#
# /gc/G_396.png 1
#
# /gc/G_397.png 1
#
# /gc/G_398.png 1
#
# /gc/G_399.png 1
#
# /gc/G_4.png 1
#
# /gc/G_40.png 1
#
# /gc/G_400.png 1
#
# /gc/G_401.png 1
#
# /gc/G_402.png 1
#
# /gc/G_403.png 1
#
# /gc/G_404.png 1
#
# /gc/G_405.png 1
#
# /gc/G_406.png 1
#
# /gc/G_407.png 1
#
# /gc/G_408.png 1
#
# /gc/G_409.png 1
#
# /gc/G_41.png 1
#
# /gc/G_410.png 1
#
# /gc/G_411.png 1
#
# /gc/G_412.png 1
#
# /gc/G_413.png 1
#
# /gc/G_414.png 1
#
# /gc/G_415.png 1
#
# /gc/G_416.png 1
#
# /gc/G_417.png 1
#
# /gc/G_418.png 1
#
# /gc/G_419.png 1
#
# /gc/G_42.png 1
#
# /gc/G_420.png 1
#
# /gc/G_421.png 1
#
# /gc/G_422.png 1
#
# /gc/G_423.png 1
#
# /gc/G_424.png 1
#
# /gc/G_425.png 1
#
# /gc/G_426.png 1
#
# /gc/G_427.png 1
#
# /gc/G_428.png 1
#
# /gc/G_429.png 1
#
# /gc/G_43.png 1
#
# /gc/G_430.png 1
#
# /gc/G_431.png 1
#
# /gc/G_432.png 1
#
# /gc/G_433.png 1
#
# /gc/G_434.png 1
#
# /gc/G_435.png 1
#
# /gc/G_436.png 1
#
# /gc/G_437.png 1
#
# /gc/G_438.png 1
# /gc/G_439.png 1
#
# /gc/G_44.png 1
#
# /gc/G_440.png 1
#
# /gc/G_441.png 1
#
# /gc/G_442.png 1
#
# /gc/G_443.png 1
#
# /gc/G_444.png 1
#
# /gc/G_445.png 1
#
# /gc/G_446.png 1
#
# /gc/G_447.png 1
#
# /gc/G_448.png 1
#
# /gc/G_449.png 1
#
# /gc/G_45.png 1
#
# /gc/G_450.png 1
#
# /gc/G_451.png 1
#
# /gc/G_452.png 1
#
# /gc/G_453.png 1
#
# /gc/G_454.png 1
#
# /gc/G_455.png 1
#
# /gc/G_456.png 1
#
# /gc/G_457.png 1
#
# /gc/G_458.png 1
#
# /gc/G_459.png 1
#
# /gc/G_46.png 1
#
# /gc/G_460.png 1
#
# /gc/G_461.png 1
#
# /gc/G_462.png 1
#
# /gc/G_463.png 1
#
# /gc/G_464.png 1
#
# /gc/G_465.png 1
#
# /gc/G_466.png 1
#
# /gc/G_467.png 1
#
# /gc/G_468.png 1
#
# /gc/G_469.png 1
#
# /gc/G_47.png 1
#
# /gc/G_470.png 1
#
# /gc/G_471.png 1
#
# /gc/G_472.png 1
#
# /gc/G_473.png 1
#
# /gc/G_474.png 1
#
# /gc/G_475.png 1
#
# /gc/G_476.png 1
#
# /gc/G_477.png 1
#
# /gc/G_478.png 1
#
# /gc/G_479.png 1
#
# /gc/G_48.png 1
#
# /gc/G_480.png 1
#
# /gc/G_481.png 1
#
# /gc/G_482.png 1
#
# /gc/G_483.png 1
#
# /gc/G_484.png 1
#
# /gc/G_485.png 1
#
# /gc/G_486.png 1
#
# /gc/G_487.png 1
#
# /gc/G_488.png 1
#
# /gc/G_489.png 1
#
# /gc/G_49.png 1
#
# /gc/G_490.png 1
#
# /gc/G_491.png 1
#
# /gc/G_492.png 1
#
# /gc/G_493.png 1
#
# /gc/G_494.png 1
#
# /gc/G_495.png 1
#
# /gc/G_496.png 1
#
# /gc/G_497.png 1
#
# /gc/G_498.png 1
#
# /gc/G_499.png 1
#
# /gc/G_5.png 1
#
# /gc/G_50.png 1
#
# /gc/G_500.png 1
#
# /gc/G_501.png 1
#
# /gc/G_502.png 1
#
# /gc/G_503.png 1
#
# /gc/G_504.png 1
#
# /gc/G_505.png 1
#
# /gc/G_506.png 1
#
# /gc/G_507.png 1
#
# /gc/G_508.png 1
#
# /gc/G_509.png 1
#
# /gc/G_51.png 1
#
# /gc/G_510.png 1
#
# /gc/G_511.png 1
#
# /gc/G_512.png 1
#
# /gc/G_513.png 1
#
# /gc/G_514.png 1
#
# /gc/G_515.png 1
#
# /gc/G_516.png 1
#
# /gc/G_517.png 1
#
# /gc/G_518.png 1
#
# /gc/G_519.png 1
#
# /gc/G_52.png 1
#
# /gc/G_520.png 1
#
# /gc/G_521.png 1
#
# /gc/G_522.png 1
#
# /gc/G_523.png 1
#
# /gc/G_524.png 1
#
# /gc/G_525.png 1
#
# /gc/G_526.png 1
#
# /gc/G_527.png 1
#
# /gc/G_528.png 1
#
# /gc/G_529.png 1
#
# /gc/G_53.png 1
#
# /gc/G_530.png 1
#
# /gc/G_531.png 1
#
# /gc/G_532.png 1
#
# /gc/G_533.png 1
#
# /gc/G_534.png 1
#
# /gc/G_535.png 1
#
# /gc/G_536.png 1
#
# /gc/G_537.png 1
#
# /gc/G_538.png 1
#
# /gc/G_539.png 1
#
# /gc/G_54.png 1
#
# /gc/G_540.png 1
#
# /gc/G_541.png 1
#
# /gc/G_542.png 1
#
# /gc/G_543.png 1
#
# /gc/G_544.png 1
#
# /gc/G_545.png 1
#
# /gc/G_546.png 1
#
# /gc/G_547.png 1
#
# /gc/G_548.png 1
#
# /gc/G_549.png 1
#
# /gc/G_55.png 1
#
# /gc/G_550.png 1
#
# /gc/G_551.png 1
#
# /gc/G_552.png 1
#
# /gc/G_553.png 1
#
# /gc/G_554.png 1
#
# /gc/G_555.png 1
#
# /gc/G_556.png 1
#
# /gc/G_557.png 1
#
# /gc/G_558.png 1
#
# /gc/G_559.png 1
#
# /gc/G_56.png 1
#
# /gc/G_560.png 1
#
# /gc/G_561.png 1
#
# /gc/G_562.png 1
#
# /gc/G_563.png 1
#
# /gc/G_564.png 1
#
# /gc/G_565.png 1
#
# /gc/G_566.png 1
#
# /gc/G_567.png 1
#
# /gc/G_568.png 1
#
# /gc/G_569.png 1
#
# /gc/G_57.png 1
#
# /gc/G_570.png 1
#
# /gc/G_571.png 1
#
# /gc/G_572.png 1
#
# /gc/G_573.png 1
#
# /gc/G_574.png 1
#
# /gc/G_575.png 1
#
# /gc/G_576.png 1
#
# /gc/G_577.png 1
#
# /gc/G_578.png 1
#
# /gc/G_579.png 1
#
# /gc/G_58.png 1
#
# /gc/G_580.png 1
#
# /gc/G_581.png 1
#
# /gc/G_582.png 1
#
# /gc/G_583.png 1
#
# /gc/G_584.png 1
#
# /gc/G_585.png 1
#
# /gc/G_586.png 1
#
# /gc/G_587.png 1
#
# /gc/G_588.png 1
#
# /gc/G_589.png 1
#
# /gc/G_59.png 1
#
# /gc/G_590.png 1
#
# /gc/G_591.png 1
#
# /gc/G_592.png 1
#
# /gc/G_593.png 1
#
# /gc/G_594.png 1
#
# /gc/G_595.png 1
#
# /gc/G_596.png 1
#
# /gc/G_597.png 1
#
# /gc/G_598.png 1
#
# /gc/G_599.png 1
#
# /gc/G_6.png 1
#
# /gc/G_60.png 1
#
# /gc/G_600.png 1
#
# /gc/G_601.png 1
#
# /gc/G_602.png 1
#
# /gc/G_603.png 1
#
# /gc/G_604.png 1
#
# /gc/G_605.png 1
#
# /gc/G_606.png 1
#
# /gc/G_607.png 1
#
# /gc/G_608.png 1
#
# /gc/G_609.png 1
#
# /gc/G_61.png 1
#
# /gc/G_610.png 1
#
# /gc/G_611.png 1
#
# /gc/G_612.png 1
#
# /gc/G_613.png 1
#
# /gc/G_614.png 1
#
# /gc/G_615.png 1
#
# /gc/G_616.png 1
#
# /gc/G_617.png 1
#
# /gc/G_618.png 1
#
# /gc/G_619.png 1
#
# /gc/G_62.png 1
#
# /gc/G_620.png 1
#
# /gc/G_621.png 1
#
# /gc/G_622.png 1
#
# /gc/G_623.png 1
#
# /gc/G_624.png 1
#
# /gc/G_625.png 1
#
# /gc/G_626.png 1
#
# /gc/G_627.png 1
#
# /gc/G_628.png 1
#
# /gc/G_629.png 1
#
# /gc/G_63.png 1
#
# /gc/G_630.png 1
#
# /gc/G_631.png 1
#
# /gc/G_632.png 1
#
# /gc/G_633.png 1
#
# /gc/G_634.png 1
#
# /gc/G_635.png 1
#
# /gc/G_636.png 1
#
# /gc/G_637.png 1
#
# /gc/G_638.png 1
#
# /gc/G_639.png 1
#
# /gc/G_64.png 1
#
# /gc/G_640.png 1
#
# /gc/G_641.png 1
#
# /gc/G_642.png 1
#
# /gc/G_643.png 1
#
# /gc/G_644.png 1
#
# /gc/G_645.png 1
#
# /gc/G_646.png 1
#
# /gc/G_647.png 1
#
# /gc/G_648.png 1
#
# /gc/G_649.png 1
#
# /gc/G_65.png 1
#
# /gc/G_650.png 1
#
# /gc/G_651.png 1
#
# /gc/G_652.png 1
#
# /gc/G_653.png 1
#
# /gc/G_654.png 1
#
# /gc/G_655.png 1
#
# /gc/G_656.png 1
#
# /gc/G_657.png 1
#
# /gc/G_658.png 1
#
# /gc/G_659.png 1
#
# /gc/G_66.png 1
#
# /gc/G_660.png 1
#
# /gc/G_661.png 1
#
# /gc/G_662.png 1
#
# /gc/G_663.png 1
#
# /gc/G_664.png 1
#
# /gc/G_665.png 1
#
# /gc/G_666.png 1
#
# /gc/G_667.png 1
#
# /gc/G_668.png 1
#
# /gc/G_669.png 1
#
# /gc/G_67.png 1
#
# /gc/G_670.png 1
#
# /gc/G_671.png 1
#
# /gc/G_672.png 1
#
# /gc/G_673.png 1
#
# /gc/G_674.png 1
#
# /gc/G_675.png 1
#
# /gc/G_676.png 1
#
# /gc/G_677.png 1
#
# /gc/G_678.png 1
#
# /gc/G_679.png 1
#
# /gc/G_68.png 1
#
# /gc/G_680.png 1
#
# /gc/G_681.png 1
#
# /gc/G_682.png 1
#
# /gc/G_683.png 1
#
# /gc/G_684.png 1
#
# /gc/G_685.png 1
#
# /gc/G_686.png 1
#
# /gc/G_687.png 1
#
# /gc/G_688.png 1
#
# /gc/G_689.png 1
#
# /gc/G_69.png 1
#
# /gc/G_690.png 1
#
# /gc/G_691.png 1
#
# /gc/G_692.png 1
#
# /gc/G_693.png 1
#
# /gc/G_694.png 1
#
# /gc/G_695.png 1
#
# /gc/G_696.png 1
#
# /gc/G_697.png 1
#
# /gc/G_698.png 1
#
# /gc/G_699.png 1
#
# /gc/G_7.png 1
#
# /gc/G_70.png 1
#
# /gc/G_700.png 1
#
# /gc/G_701.png 1
#
# /gc/G_702.png 1
#
# /gc/G_703.png 1
#
# /gc/G_704.png 1
#
# /gc/G_705.png 1
#
# /gc/G_706.png 1
#
# /gc/G_707.png 1
#
# /gc/G_708.png 1
#
# /gc/G_709.png 1
#
# /gc/G_71.png 1
#
# /gc/G_710.png 1
#
# /gc/G_711.png 1
#
# /gc/G_712.png 1
#
# /gc/G_713.png 1
#
# /gc/G_714.png 1
#
# /gc/G_715.png 1
#
# /gc/G_716.png 1
#
# /gc/G_717.png 1
#
# /gc/G_718.png 1
#
# /gc/G_719.png 1
#
# /gc/G_72.png 1
#
# /gc/G_720.png 1
#
# /gc/G_721.png 1
#
# /gc/G_722.png 1
#
# /gc/G_723.png 1
#
# /gc/G_724.png 1
#
# /gc/G_725.png 1
#
# /gc/G_726.png 1
#
# /gc/G_727.png 1
#
# /gc/G_728.png 1
#
# /gc/G_729.png 1
#
# /gc/G_73.png 1
#
# /gc/G_730.png 1
#
# /gc/G_731.png 1
#
# /gc/G_732.png 1
#
# /gc/G_733.png 1
#
# /gc/G_734.png 1
#
# /gc/G_735.png 1
#
# /gc/G_736.png 1
#
# /gc/G_737.png 1
#
# /gc/G_738.png 1
#
# /gc/G_739.png 1
#
# /gc/G_74.png 1
#
# /gc/G_740.png 1
#
# /gc/G_741.png 1
#
# /gc/G_742.png 1
#
# /gc/G_743.png 1
#
# /gc/G_744.png 1
#
# /gc/G_745.png 1
#
# /gc/G_746.png 1
#
# /gc/G_747.png 1
#
# /gc/G_748.png 1
#
# /gc/G_749.png 1
#
# /gc/G_75.png 1
#
# /gc/G_750.png 1
#
# /gc/G_751.png 1
#
# /gc/G_752.png 1
#
# /gc/G_753.png 1
#
# /gc/G_754.png 1
#
# /gc/G_755.png 1
#
# /gc/G_756.png 1
#
# /gc/G_757.png 1
#
# /gc/G_758.png 1
#
# /gc/G_759.png 1
#
# /gc/G_76.png 1
#
# /gc/G_760.png 1
#
# /gc/G_761.png 1
#
# /gc/G_762.png 1
#
# /gc/G_763.png 1
#
# /gc/G_764.png 1
#
# /gc/G_765.png 1
#
# /gc/G_766.png 1
#
# /gc/G_767.png 1
#
# /gc/G_768.png 1
#
# /gc/G_769.png 1
#
# /gc/G_77.png 1
#
# /gc/G_770.png 1
#
# /gc/G_771.png 1
#
# /gc/G_772.png 1
#
# /gc/G_773.png 1
#
# /gc/G_774.png 1
#
# /gc/G_775.png 1
#
# /gc/G_776.png 1
#
# /gc/G_777.png 1
#
# /gc/G_778.png 1
#
# /gc/G_779.png 1
#
# /gc/G_78.png 1
#
# /gc/G_780.png 1
#
# /gc/G_781.png 1
#
# /gc/G_782.png 1
#
# /gc/G_783.png 1
#
# /gc/G_784.png 1
#
# /gc/G_785.png 1
#
# /gc/G_786.png 1
#
# /gc/G_787.png 1
#
# /gc/G_788.png 1
#
# /gc/G_789.png 1
#
# /gc/G_79.png 1
#
# /gc/G_790.png 1
#
# /gc/G_791.png 1
#
# /gc/G_792.png 1
#
# /gc/G_793.png 1
#
# /gc/G_794.png 1
#
# /gc/G_795.png 1
#
# /gc/G_796.png 1
#
# /gc/G_797.png 1
#
# /gc/G_798.png 1
#
# /gc/G_799.png 1
#
# /gc/G_8.png 1
#
# /gc/G_80.png 1
#
# /gc/G_800.png 1
#
# /gc/G_801.png 1
#
# /gc/G_802.png 1
#
# /gc/G_803.png 1
#
# /gc/G_804.png 1
#
# /gc/G_805.png 1
#
# /gc/G_806.png 1
#
# /gc/G_807.png 1
#
# /gc/G_808.png 1
#
# /gc/G_809.png 1
#
# /gc/G_81.png 1
#
# /gc/G_810.png 1
#
# /gc/G_811.png 1
#
# /gc/G_812.png 1
#
# /gc/G_813.png 1
#
# /gc/G_814.png 1
#
# /gc/G_815.png 1
#
# /gc/G_816.png 1
#
# /gc/G_817.png 1
#
# /gc/G_818.png 1
#
# /gc/G_819.png 1
#
# /gc/G_82.png 1
#
# /gc/G_820.png 1
#
# /gc/G_821.png 1
#
# /gc/G_822.png 1
#
# /gc/G_823.png 1
#
# /gc/G_824.png 1
#
# /gc/G_825.png 1
#
# /gc/G_826.png 1
#
# /gc/G_827.png 1
#
# /gc/G_828.png 1
#
# /gc/G_829.png 1
#
# /gc/G_83.png 1
#
# /gc/G_830.png 1
#
# /gc/G_831.png 1
#
# /gc/G_832.png 1
#
# /gc/G_833.png 1
#
# /gc/G_834.png 1
#
# /gc/G_835.png 1
#
# /gc/G_836.png 1
#
# /gc/G_837.png 1
#
# /gc/G_838.png 1
#
# /gc/G_839.png 1
#
# /gc/G_84.png 1
#
# /gc/G_840.png 1
#
# /gc/G_841.png 1
#
# /gc/G_842.png 1
#
# /gc/G_843.png 1
#
# /gc/G_844.png 1
#
# /gc/G_845.png 1
#
# /gc/G_846.png 1
#
# /gc/G_847.png 1
#
# /gc/G_848.png 1
#
# /gc/G_849.png 1
#
# /gc/G_85.png 1
#
# /gc/G_850.png 1
#
# /gc/G_851.png 1
#
# /gc/G_852.png 1
#
# /gc/G_853.png 1
#
# /gc/G_854.png 1
#
# /gc/G_855.png 1
#
# /gc/G_856.png 1
#
# /gc/G_857.png 1
#
# /gc/G_858.png 1
#
# /gc/G_859.png 1
#
# /gc/G_86.png 1
#
# /gc/G_860.png 1
#
# /gc/G_861.png 1
#
# /gc/G_862.png 1
#
# /gc/G_863.png 1
#
# /gc/G_864.png 1
#
# /gc/G_865.png 1
#
# /gc/G_866.png 1
#
# /gc/G_867.png 1
#
# /gc/G_868.png 1
#
# /gc/G_869.png 1
#
# /gc/G_87.png 1
#
# /gc/G_870.png 1
#
# /gc/G_871.png 1
#
# /gc/G_872.png 1
#
# /gc/G_873.png 1
#
# /gc/G_874.png 1
#
# /gc/G_875.png 1
#
# /gc/G_876.png 1
#
# /gc/G_877.png 1
#
# /gc/G_878.png 1
#
# /gc/G_879.png 1
#
# /gc/G_88.png 1
#
# /gc/G_880.png 1
#
# /gc/G_881.png 1
#
# /gc/G_882.png 1
#
# /gc/G_883.png 1
#
# /gc/G_884.png 1
#
# /gc/G_885.png 1
#
# /gc/G_886.png 1
#
# /gc/G_887.png 1
#
# /gc/G_888.png 1
#
# /gc/G_889.png 1
#
# /gc/G_89.png 1
#
# /gc/G_890.png 1
#
# /gc/G_891.png 1
#
# /gc/G_892.png 1
#
# /gc/G_893.png 1
#
# /gc/G_894.png 1
#
# /gc/G_895.png 1
#
# /gc/G_896.png 1
#
# /gc/G_897.png 1
#
# /gc/G_898.png 1
#
# /gc/G_899.png 1
#
# /gc/G_9.png 1
#
# /gc/G_90.png 1
#
# /gc/G_900.png 1
#
# /gc/G_901.png 1
#
# /gc/G_902.png 1
#
# /gc/G_903.png 1
#
# /gc/G_904.png 1
#
# /gc/G_905.png 1
#
# /gc/G_906.png 1
#
# /gc/G_907.png 1
#
# /gc/G_908.png 1
#
# /gc/G_909.png 1
#
# /gc/G_91.png 1
#
# /gc/G_910.png 1
#
# /gc/G_911.png 1
#
# /gc/G_912.png 1
#
# /gc/G_913.png 1
#
# /gc/G_914.png 1
#
# /gc/G_915.png 1
#
# /gc/G_916.png 1
#
# /gc/G_917.png 1
#
# /gc/G_918.png 1
#
# /gc/G_919.png 1
#
# /gc/G_92.png 1
#
# /gc/G_920.png 1
#
# /gc/G_921.png 1
#
# /gc/G_922.png 1
#
# /gc/G_923.png 1
#
# /gc/G_924.png 1
#
# /gc/G_925.png 1
#
# /gc/G_926.png 1
#
# /gc/G_927.png 1
#
# /gc/G_928.png 1
#
# /gc/G_929.png 1
#
# /gc/G_93.png 1
#
# /gc/G_930.png 1
#
# /gc/G_931.png 1
#
# /gc/G_932.png 1
#
# /gc/G_933.png 1
#
# /gc/G_934.png 1
#
# /gc/G_935.png 1
#
# /gc/G_936.png 1
#
# /gc/G_937.png 1
#
# /gc/G_938.png 1
#
# /gc/G_939.png 1
#
# /gc/G_94.png 1
#
# /gc/G_940.png 1
#
# /gc/G_941.png 1
#
# /gc/G_942.png 1
#
# /gc/G_943.png 1
#
# /gc/G_944.png 1
#
# /gc/G_945.png 1
#
# /gc/G_946.png 1
#
# /gc/G_947.png 1
#
# /gc/G_948.png 1
#
# /gc/G_949.png 1
#
# /gc/G_95.png 1
#
# /gc/G_950.png 1
#
# /gc/G_951.png 1
#
# /gc/G_952.png 1
#
# /gc/G_953.png 1
#
# /gc/G_954.png 1
#
# /gc/G_955.png 1
#
# /gc/G_956.png 1
#
# /gc/G_957.png 1
#
# /gc/G_958.png 1
#
# /gc/G_959.png 1
#
# /gc/G_96.png 1
#
# /gc/G_960.png 1
#
# /gc/G_961.png 1
#
# /gc/G_962.png 1
#
# /gc/G_963.png 1
#
# /gc/G_964.png 1
#
# /gc/G_965.png 1
#
# /gc/G_966.png 1
#
# /gc/G_967.png 1
#
# /gc/G_968.png 1
#
# /gc/G_969.png 1
#
# /gc/G_97.png 1
#
# /gc/G_970.png 1
#
# /gc/G_971.png 1
#
# /gc/G_972.png 1
#
# /gc/G_973.png 1
#
# /gc/G_974.png 1
#
# /gc/G_975.png 1
#
# /gc/G_976.png 1
#
# /gc/G_977.png 1
#
# /gc/G_978.png 1
#
# /gc/G_979.png 1
#
# /gc/G_98.png 1
#
# /gc/G_980.png 1
#
# /gc/G_981.png 1
#
# /gc/G_982.png 1
#
# /gc/G_983.png 1
#
# /gc/G_984.png 1
#
# /gc/G_985.png 1
#
# /gc/G_986.png 1
#
# /gc/G_987.png 1
#
# /gc/G_988.png 1
#
# /gc/G_989.png 1
#
# /gc/G_99.png 1
#
# /gc/G_990.png 1
#
# /gc/G_991.png 1
#
# /gc/G_992.png 1
#
# /gc/G_993.png 1
#
# /gc/G_994.png 1
#
# /gc/G_995.png 1
#
# /gc/G_996.png 1
#
# /gc/G_997.png 1
#
# /gc/G_998.png 1
#
# /gc/G_999.png 1
#
# finished!

# %%
def generate_Bad(dir,label):
    files = os.listdir(dir+'/bc')
    with open(dir+'val.txt','a+') as g:
        for file in files:
            filename = os.path.split(file)[0]
            filetype = os.path.split(file)[1]
            if filetype == '.txt':
                continue
            name = '/bc' + '/' + file + ' ' + str(int(label)) + '\n'
            print(name)
    print("finished!")
    
img_path = r'C:\Users\cjx02\Desktop\student project_machine learning_06_2022\data'

if __name__ == '__main__':
    i=0
    generate_Bad(img_path,i)
# Out:
# /bc/B_0.png 0
#
# /bc/B_1.png 0
#
# /bc/B_10.png 0
#
# /bc/B_11.png 0
#
# /bc/B_12.png 0
#
# /bc/B_13.png 0
#
# /bc/B_14.png 0
#
# /bc/B_15.png 0
#
# /bc/B_16.png 0
#
# /bc/B_17.png 0
#
# /bc/B_18.png 0
#
# /bc/B_19.png 0
#
# /bc/B_2.png 0
#
# /bc/B_20.png 0
#
# /bc/B_21.png 0
#
# /bc/B_22.png 0
#
# /bc/B_23.png 0
#
# /bc/B_24.png 0
#
# /bc/B_25.png 0
#
# /bc/B_26.png 0
#
# /bc/B_27.png 0
#
# /bc/B_28.png 0
#
# /bc/B_29.png 0
#
# /bc/B_3.png 0
#
# /bc/B_30.png 0
#
# /bc/B_31.png 0
#
# /bc/B_4.png 0
#
# /bc/B_5.png 0
#
# /bc/B_6.png 0
#
# /bc/B_7.png 0
#
# /bc/B_8.png 0
#
# /bc/B_9.png 0
#
# finished!

# %%
import torch
from torch.utils.data import DataLoader
from torchvision import transforms, datasets
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

data_transform=transforms.Compose([
    transforms.Resize((224,224)),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
])

train_dataset = datasets.ImageFolder(root='/Users/haoyilin/PycharmProjects/Tensorflow1/data/train',transform=data_transform)
train_dataloader = DataLoader(dataset=train_dataset,
                              batch_size=4,
                              shuffle=True,
                              num_workers=4)


def show_batch_images(sample_batch):
    labels_batch = sample_batch[1]
    images_batch = sample_batch[0]

    for i in range(3):
        label_ = labels_batch[i].item()
        image_ = np.transpose(images_batch[i], (1, 2, 0))
        ax = plt.subplot(1, 4, i + 1)
        ax.imshow(image_)
        ax.set_title(str(label_))
        ax.axis('off')
        plt.pause(0.01)


plt.figure()
for i_batch, sample_batch in enumerate(train_dataloader):
    show_batch_images(sample_batch)

    plt.show()


#%%

# %%
# 验证集
import torch
from torch.utils.data import DataLoader
from torchvision import transforms, datasets
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline
# https://pytorch.org/tutorials/beginner/data_loading_tutorial.html

# data_transform = transforms.Compose([
#     transforms.RandomResizedCrop(224),
#     transforms.RandomHorizontalFlip(),
#     transforms.ToTensor(),
#     transforms.Normalize(mean=[0.485, 0.456, 0.406],
#                          std=[0.229, 0.224, 0.225])
# ])

data_transform = transforms.Compose([
    transforms.Resize((224,224)),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),

])

val_dataset = datasets.ImageFolder(root='/Users/haoyilin/PycharmProjects/Tensorflow1/data/validation',transform=data_transform)
val_dataloader = DataLoader(dataset=val_dataset,
                              batch_size=4,
                              shuffle=True,
                              num_workers=4)


def show_batch_images(sample_batch):
    labels_batch = sample_batch[1]
    images_batch = sample_batch[0]

    for i in range(3):
        label_ = labels_batch[i].item()
        image_ = np.transpose(images_batch[i], (1, 2, 0))
        ax = plt.subplot(1, 4, i + 1)
        ax.imshow(image_)
        ax.set_title(str(label_))
        ax.axis('off')
        plt.pause(0.01)


plt.figure()
for i_batch, sample_batch in enumerate(val_dataloader):
    show_batch_images(sample_batch)

    plt.show()

# %%
import torch
from torch.utils.data import DataLoader
from torchvision import transforms, datasets
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

data_transform = transforms.Compose([
    transforms.Resize((224,224)),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),

])

test_dataset = datasets.ImageFolder(root='/Users/haoyilin/PycharmProjects/Tensorflow1/data/test',transform=data_transform)
test_dataloader = DataLoader(dataset=test_dataset,
                              batch_size=4,
                              shuffle=True,
                              num_workers=4)


'''def show_batch_images(sample_batch):
    labels_batch = sample_batch[1]
    images_batch = sample_batch[0]

    for i in range(3):
        label_ = labels_batch[i].item()
        image_ = np.transpose(images_batch[i], (1, 2, 0))
        ax = plt.subplot(1, 4, i + 1)
        ax.imshow(image_)
        ax.set_title(str(label_))
        ax.axis('off')
        plt.pause(0.01)
        


plt.figure()
for i_batch, sample_batch in enumerate(test_dataloader):
    show_batch_images(sample_batch)

    plt.show()'''
# Out:
# "def show_batch_images(sample_batch):\n    labels_batch = sample_batch[1]\n    images_batch = sample_batch[0]\n\n    for i in range(3):\n        label_ = labels_batch[i].item()\n        image_ = np.transpose(images_batch[i], (1, 2, 0))\n        ax = plt.subplot(1, 4, i + 1)\n        ax.imshow(image_)\n        ax.set_title(str(label_))\n        ax.axis('off')\n        plt.pause(0.01)\n        \n\n\nplt.figure()\nfor i_batch, sample_batch in enumerate(test_dataloader):\n    show_batch_images(sample_batch)\n\n    plt.show()"

# %%
import torch
import torch.optim as optim
import torch.nn as nn
from torch.utils.data import DataLoader
from torchvision.datasets import ImageFolder
import torchvision.models as models
import torchvision.transforms as transforms
import numpy as np
import copy
import matplotlib.pyplot as plt
import os
import torchnet

#%%

print('train_dataset: {}'.format(len(train_dataset)))
print('val_dataset: {}'.format(len(val_dataset)))
print('test_dataset: {}'.format(len(test_dataset)))

#%%

batch_size = 8
data_root = '/Users/haoyilin/PycharmProjects/Tensorflow1/data/train'
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')



#%%

# 载入训练模型 
model = models.squeezenet1_1(pretrained=True)
model.classifier[1] = nn.Conv2d(in_channels=512, out_channels=2, kernel_size=(1, 1), stride=(1, 1))
model.num_classes = 2
print(model)
model.to(device)

# 优化方法、损失函数
optimizer = optim.SGD(model.parameters(),lr=0.001, momentum=0.9)
loss_fc = nn.CrossEntropyLoss()
scheduler = optim.lr_scheduler.StepLR(optimizer,10, 0.1)


#%%

## 训练
num_epoch = 2
# 训练日志保存
logfile_dir = '/Users/haoyilin/PycharmProjects/Tensorflow1/data/log/'
# file_train_loss = open('/Users/lyndsey/NewScenery/ml-homework/Tooth-Detection/log/train_loss.txt', 'w')
# file_train_acc = open('/Users/lyndsey/NewScenery/ml-homework/Tooth-Detection/log/train_acc.txt', 'w')

# file_val_loss = open('/Users/lyndsey/NewScenery/ml-homework/Tooth-Detection/log/val_loss.txt', 'w')
# file_val_acc = open('/Users/lyndsey/NewScenery/ml-homework/Tooth-Detection/log/val_acc.txt', 'w')

acc_best_wts = model.state_dict()
best_acc = 0
iter_count = 0

for epoch in range(num_epoch):
    train_loss = 0.0
    train_acc = 0.0
    train_correct = 0
    train_total = 0

    val_loss = 0.0
    val_acc = 0.0
    val_correct = 0
    val_total = 0

    scheduler.step()
    for i, sample_batch in enumerate(train_dataloader):
        # print(sample_batch)
        inputs = sample_batch[0].to(device)
        labels = sample_batch[1].to(device)
        #print(inputs,labels)
        

        # 模型设置为train
        model.train()

        # forward
        outputs = model(inputs)

        # print(labels)
        # loss
        loss = loss_fc(outputs, labels)

        # forward update
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # 统计
        train_loss += loss.item()
        train_correct += (torch.max(outputs, 1)[1] == labels).sum().item()
        train_total += labels.size(0)

        print('iter:{}'.format(i))
        
        if i % 10 == 9:
            for sample_batch in val_dataloader:
                inputs = sample_batch[0].to(device)
                labels = sample_batch[1].to(device)

                model.eval()
                outputs = model(inputs)
                loss = loss_fc(outputs, labels)
                _, prediction = torch.max(outputs, 1)
                val_correct += ((labels == prediction).sum()).item()
                val_total += inputs.size(0)
                val_loss += loss.item()

            val_acc = val_correct / val_total
            print('[{},{}] train_loss = {:.5f} train_acc = {:.5f} val_loss = {:.5f} val_acc = {:.5f}'.format(
                epoch + 1, i + 1, train_loss / 100,train_correct / train_total, val_loss/len(val_dataloader),
                val_correct / val_total))
            if val_acc > best_acc:
                best_acc = val_acc
                acc_best_wts = copy.deepcopy(model.state_dict())

            with open(logfile_dir +'train_loss.txt','a') as f:
                f.write(str(train_loss / 100) + '\n')
            with open(logfile_dir +'train_acc.txt','a') as f:
                f.write(str(train_correct / train_total) + '\n')
            with open(logfile_dir +'val_loss.txt','a') as f:
                f.write(str(val_loss/len(val_dataloader)) + '\n')
            with open(logfile_dir +'val_acc.txt','a') as f:
                f.write(str(val_correct / val_total) + '\n')

            iter_count += 200
            
            train_loss = 0.0
            train_total = 0
            train_correct = 0
            val_correct = 0
            val_total = 0
            val_loss = 0


print('Train finish!')
# 保存模型
model_file = '/Users/haoyilin/PycharmProjects/Tensorflow1/data/models/'
# with open(model_file+'/model_squeezenet_teeth_1.pth','a') as f:
#     torch.save(acc_best_wts,f)
torch.save(acc_best_wts, model_file + '/model_squeezenet_utk_face_1.pth')
print('Model save ok!')

#%%

#测试

model = models.squeezenet1_1(pretrained=True)
model.classifier[1] = nn.Conv2d(in_channels=512, out_channels=2, kernel_size=(1, 1), stride=(1, 1))
model.num_classes = 2
model.load_state_dict(torch.load(model_file+'/model_squeezenet_utk_face_1.pth', map_location='cpu'))
print(model)
model.eval()


test_dataloader = DataLoader(dataset=test_dataset, batch_size=4, shuffle=False, num_workers=4)

correct = 0
total = 0
acc = 0.0
for i, sample in enumerate(test_dataloader):
    inputs, labels = sample[0], sample[1]

    outputs = model(inputs)

    _, prediction = torch.max(outputs, 1)
    correct += (labels == prediction).sum().item()
    total += labels.size(0)

acc = correct / total
print('test finish, total:{}, correct:{}, acc:{:.3f}'.format(total, correct, acc))
# Out:
# train_dataset: 83
# val_dataset: 39
# test_dataset: 13
# SqueezeNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#     (3): Fire(
#       (squeeze): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(16, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (4): Fire(
#       (squeeze): Conv2d(128, 16, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(16, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#     (6): Fire(
#       (squeeze): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(32, 128, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(32, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (7): Fire(
#       (squeeze): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(32, 128, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(32, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (8): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#     (9): Fire(
#       (squeeze): Conv2d(256, 48, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(48, 192, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(48, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (10): Fire(
#       (squeeze): Conv2d(384, 48, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(48, 192, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(48, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (11): Fire(
#       (squeeze): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(64, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (12): Fire(
#       (squeeze): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(64, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#   )
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Conv2d(512, 2, kernel_size=(1, 1), stride=(1, 1))
#     (2): ReLU(inplace=True)
#     (3): AdaptiveAvgPool2d(output_size=(1, 1))
#   )
# )
# iter:0
# iter:1
# iter:2
# iter:3
# iter:4
# iter:5
# iter:6
# iter:7
# iter:8
# iter:9
# [1,10] train_loss = 0.08291 train_acc = 0.57500 val_loss = 0.80701 val_acc = 0.00000
# iter:10
# iter:11
# iter:12
# iter:13
# iter:14
# iter:15
# iter:16
# iter:17
# iter:18
# iter:19
# [1,20] train_loss = 0.06538 train_acc = 0.62500 val_loss = 0.97192 val_acc = 0.00000
# iter:20
# iter:0
# iter:1
# iter:2
# iter:3
# iter:4
# iter:5
# iter:6
# iter:7
# iter:8
# iter:9
# [2,10] train_loss = 0.06545 train_acc = 0.72500 val_loss = 0.98157 val_acc = 0.00000
# iter:10
# iter:11
# iter:12
# iter:13
# iter:14
# iter:15
# iter:16
# iter:17
# iter:18
# iter:19
# [2,20] train_loss = 0.06468 train_acc = 0.62500 val_loss = 1.32373 val_acc = 0.00000
# iter:20
# Train finish!
# Model save ok!
# SqueezeNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#     (3): Fire(
#       (squeeze): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(16, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (4): Fire(
#       (squeeze): Conv2d(128, 16, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(16, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#     (6): Fire(
#       (squeeze): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(32, 128, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(32, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (7): Fire(
#       (squeeze): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(32, 128, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(32, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (8): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#     (9): Fire(
#       (squeeze): Conv2d(256, 48, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(48, 192, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(48, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (10): Fire(
#       (squeeze): Conv2d(384, 48, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(48, 192, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(48, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (11): Fire(
#       (squeeze): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(64, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (12): Fire(
#       (squeeze): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(64, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#   )
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Conv2d(512, 2, kernel_size=(1, 1), stride=(1, 1))
#     (2): ReLU(inplace=True)
#     (3): AdaptiveAvgPool2d(output_size=(1, 1))
#   )
# )
# test finish, total:13, correct:9, acc:0.692
